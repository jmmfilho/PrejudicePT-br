# %%
import emoji, re, string, time
import pandas as pd
import numpy as np
from scipy.stats import randint
import pickle

#nlp
import nltk
from nltk.corpus import stopwords
import spacy

#dataviz
import matplotlib.pyplot as plt
import seaborn as sns

#features
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import linear_kernel
from sklearn import metrics

from sklearn.decomposition import PCA

#models
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import ComplementNB
from sklearn.ensemble  import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import StratifiedKFold


get_ipython().run_line_magic('matplotlib', 'inline')
sns.set(style="darkgrid")

from scipy.sparse import hstack

# cross_validation
from sklearn.model_selection import cross_validate


import os, psutil
os.environ["LOKY_MAX_CPU_COUNT"] = str(psutil.cpu_count(logical=False))


import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, learning_curve

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
from sklearn.utils import shuffle

# %%
filepath = '../../Datasets/Telegram_Tratado_Rotulado_Revisado_Final.csv'
df = pd.read_csv(filepath)

# %%
# 1. Visão Geral do Dataset
print("1. Visão Geral do Dataset:")
print(f"- Número de Linhas: {df.shape[0]}")
print(f"- Número de Colunas: {df.shape[1]}")
print("\n- Primeiros 5 registros:")
print(df.head())

# 2. Informações Básicas
print("\n2. Informações Básicas:")
print(df.info())

# 3. Estatísticas Descritivas
print("\n3. Estatísticas Descritivas:")
print(df.describe(include='all'))  # Inclui colunas categóricas e numéricas

mensagens_coluna = 'text_content_anonymous'  
df[mensagens_coluna] = df[mensagens_coluna].astype(str)

# Tokenizar mensagens (simples divisão por espaços)
df['num_tokens'] = df[mensagens_coluna].apply(lambda x: len(x.split()))

# 1. Quantidade de mensagens únicas
mensagens_unicas = df[mensagens_coluna].nunique()

# 2. Média e desvio-padrão do número de tokens
media_tokens = df['num_tokens'].mean()
desvio_tokens = df['num_tokens'].std()

print(media_tokens)
print(desvio_tokens)

# 3. Número mínimo de tokens
min_tokens = df['num_tokens'].min()

print(min_tokens)

# 4. Número máximo de tokens
max_tokens = df['num_tokens'].max()
print(max_tokens)

# 4. Checagem de Valores Nulos
print("\n4. Valores Nulos:")
print(df.isnull().sum())

# 5. Distribuição de Variáveis Numéricas
print("\n5. Distribuição de Variáveis Numéricas:")
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns
df[numeric_cols].hist(bins=20, figsize=(15, 10))
plt.suptitle("Distribuição de Variáveis Numéricas")
plt.show()

# 6. Distribuição de Variáveis Categóricas
print("\n6. Distribuição de Variáveis Categóricas:")
categorical_cols = df.select_dtypes(include=['object', 'category']).columns
for col in categorical_cols:
    print(f"\nColuna: {col}")
    print(df[col].value_counts())

# 7. Matriz de Correlação
if not numeric_cols.empty:
    print("\n7. Matriz de Correlação:")
    corr_matrix = df[numeric_cols].corr()
    sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm")
    plt.title("Matriz de Correlação")
    plt.show()

# 8. Outliers (Boxplots para Numéricos)
print("\n8. Outliers (Boxplots para Variáveis Numéricas):")
for col in numeric_cols:
    plt.figure(figsize=(8, 4))
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot - {col}")
    plt.show()

# 9. Distribuição de Classes (se houver uma variável target)
if 'target' in df.columns:
    print("\n9. Distribuição de Classes (Target):")
    print(df['target'].value_counts(normalize=True))
    df['target'].value_counts().plot(kind='bar', title="Distribuição da Variável Target")
    plt.show()

# 10. Checagem de Dados Duplicados
print("\n10. Dados Duplicados:")
duplicates = df.duplicated().sum()
print(f"- Total de Registros Duplicados: {duplicates}")
# Out:
# 1. Visão Geral do Dataset:
# - Número de Linhas: 3000
# - Número de Colunas: 2
#
# - Primeiros 5 registros:
#                               text_content_anonymous  preconceito
# 0  Sim, eu sou um "decepcionado"!\n\nEu vejo pess...            0
# 1  Em épocas com muitos eventos grandes, altas qu...            0
# 2  Algumas premissas que ele adotou:\n- Ser de di...            0
# 3  Apocalipse 22:11. Cristo fez expiação por Seu ...            0
# 4  :sun_with_face:S:rose:H:cherry_blossom:A:sunfl...            0
#
# 2. Informações Básicas:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 2 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   text_content_anonymous  3000 non-null   object
#  1   preconceito             3000 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 47.0+ KB
# None
#
# 3. Estatísticas Descritivas:
#                                    text_content_anonymous  preconceito
# count                                                3000  3000.000000
# unique                                               2997          NaN
# top     Datena pode ser um pilantra mas ele sabe os po...          NaN
# freq                                                    2          NaN
# mean                                                  NaN     0.500000
# std                                                   NaN     0.500083
# min                                                   NaN     0.000000
# 25%                                                   NaN     0.000000
# 50%                                                   NaN     0.500000
# 75%                                                   NaN     1.000000
# max                                                   NaN     1.000000
# 50.81
# 40.03777684293724
# 1
# 183
#
# 4. Valores Nulos:
# text_content_anonymous    0
# preconceito               0
# num_tokens                0
# dtype: int64
#
# 5. Distribuição de Variáveis Numéricas:
# 6. Distribuição de Variáveis Categóricas:
#
# Coluna: text_content_anonymous
# text_content_anonymous
# Datena pode ser um pilantra mas ele sabe os podres da velha politica e se abrir a boca ele manda um monte p cadeia e como o luladrao vai tira varios programas do ar se eleito ou seja o negocio sera feio p midia e quem dizia q o nosso Pres era contra vao se arrepender caso ele entre...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                2
# Presidente Bolsonaro tem razão. Procurem vê o plano de governo do Luladrão. É de da nojo                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     2
# A esquerdalha está conseguindo detonar os grupos de direita se aproveitando das vaidades pessoais dos próprios direitistas. É muito fácil desestabilizar os grupos de direita.  Pensem nisso                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 2
# Sim, eu sou um "decepcionado"!\n\nEu vejo pessoas tentando o "jeitinho brasileiro" para ganhar dinheiro na internet;\n\nEu vejo pessoas discutindo pessoas e não ideias, na internet;\n\nEu vejo pessoas descartando amigos e parentes por opinião política, através da dicotomia entre Direita e Esquerda;\n\nEu vejo pessoas tentando fundamentar suas teorias sem nenhum embasamento científico;\n\nEu vejo pessoas tomando a picada não aprovada, completamente experimental, vinda da experiência já escrita no "Os Protocolos...";\n\nVejo pessoas venerando seus algozes e humilhando seus benfeitores;\n\nVejo pessoas desconfiando dos justos e sendo guiadas por cegos;\n\nVejo pessoas imorais, que apontam o cisco nos olhos de seus irmãos mas são incapazes de retirarem a trave de vossos olhos; \n\nVejo pessoas hipócritas, que mentem dizendo serem pesquisadores da verdade mas são infiltrados em movimentos para destruir a própria verdade....\n\nEu vejo tudo isso...quando você vai enxergar?\n\nNão tem como não se decepcionar.    1
# Infiltrados tentando influenciar Cristãos patriotas, é muita insanidade, queima eles Jesus, queima sem piedade                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ..
# Você pesquisou filho de satanás foi ver o vídeo, nem toque em no do sagrado filho da besta                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   1
# Me ajudem a esquerda diz que o Presidente Bolsonaro quer acabar com os funcionárismos público pela PEC 32 Distorcendo os fatos! \nPeço ajuda por favor a esclarecer :folded_hands::Brazil:                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   1
# Nos EUA, o episódio do programa "Investigação Paralela" sobre a morte de Celso Daniel segue no ar.\n\nNo Brasil, ele foi CENSURADO pela justiça eleitoral, a pedido do PT.\n\nO Brasil começa a se transformar na China, para deleite da militância de redação e da esquerda em geral.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       1
# _________\n\nEstá escrito na palavra de Deus, o Senhor dos céus e da terra.\n\nApóstolo Paulo servo de Jesus Cristo o Filho de Deus \n\n\n\n\n\n\n\n\n\nTudo o que fizerem, façam de todo o coração, como para o Senhor, e não para os homens,\n\n\n\n\n\n\n\n\n\n\nEstá escrito em Colossenses 3:23 Bíblia Sagrada\n\n_________                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             1
# Será uma guerra do bem contra o mal até o final, mas somos muitos e somos inteligentes. Vamos ganhar. Proponho para todos os bolsonaristas boicotar a televisão aberta brasileira, pois deveria estar bem claro em todos os noticiários que o povo está votando em um ladrão.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                1
# Name: count, Length: 2997, dtype: int64
#
# 7. Matriz de Correlação:
# 8. Outliers (Boxplots para Variáveis Numéricas):
# 10. Dados Duplicados:
# - Total de Registros Duplicados: 3

# %% [markdown]
# # Funções que serão usadas para processamento de texto

# %%
unicode_emoji = {}
for key, value in emoji.EMOJI_DATA.items():
    try:
        unicode_emoji[key] = value['pt']
    except:
        pass

#emojis and punctuation
emojis_list = list(unicode_emoji)
punct = list(string.punctuation)
emojis_punct = emojis_list + punct

def processEmojisPunctuation(text, remove_punct = True):
    '''
    Put spaces between emojis. Removes punctuation.
    '''
    #get all unique chars
    chars = set(text)
    #for each unique char in text, do:
    for c in chars:
        #remove punctuation
        if remove_punct:
            if c in emojis_list:
                text = text.replace(c, ' ' + c + ' ')
            if c in punct:
                text = text.replace(c, ' ')

        #put spaces between punctuation
        else:
            if c in emojis_punct:
                text = text.replace(c, ' ' + c + ' ')          

    text = text.replace('  ', ' ')
    return text

#stop words removal
stop_words = list(stopwords.words('portuguese'))
new_stopwords = ['aí','pra','vão','vou','onde','lá','aqui',
                 'tá','pode','pois','so','deu','agora','todo',
                 'nao','ja','vc', 'bom', 'ai','kkk','kkkk','ta', 'voce', 'alguem', 'ne', 'pq',
                 'cara','to','mim','la','vcs','tbm', 'tudo']
stop_words = stop_words + new_stopwords
final_stop_words = []
for sw in stop_words:
    sw = ' '+ sw + ' '
    final_stop_words.append(sw)

def removeStopwords(text):
    for sw in final_stop_words:
        text = text.replace(sw,' ')
    text = text.replace('  ',' ')
    return text

#lemmatization
nlp = spacy.load('pt_core_news_sm')
def lemmatization(text):
    doc = nlp(text)
    for token in doc:
        if token.text != token.lemma_:
            text = text.replace(token.text, token.lemma_)
    return text


def domainUrl(text):
    '''
    Substitutes an URL in a text for the domain of this URL
    Input: an string
    Output: the string with the modified URL
    '''    
    if 'http' in text:
        re_url = '[^\s]*https*://[^\s]*'
        matches = re.findall(re_url, text, flags=re.IGNORECASE)
        for m in matches:
            domain = m.split('//')
            domain = domain[1].split('/')[0]
            text = re.sub(re_url, domain, text, 1)
        return text
    else:
        return text 

def preprocess(text):
    text = text.lower().strip()
    text = domainUrl(text)
    text = processEmojisPunctuation(text)
    text = removeStopwords(text)
    text = lemmatization(text)
    return text

# %% [markdown]
# # Definindo quais experimentos serão feitos

# %%
experiments = [
            'ml-tfidf-uni_gram',
            'ml-tfidf-uni_gram-processed',
            'ml-tfidf-unibi_gram',
            'ml-tfidf-unibi_gram-processed',
            'ml-tfidf-unibitri_gram',
            'ml-tfidf-unibitri_gram-processed',

            
            'ml-bow-uni_gram',
            'ml-bow-uni_gram-processed',
            'ml-bow-unibi_gram',
            'ml-bow-unibi_gram-processed',
            'ml-bow-unibitri_gram',
            'ml-bow-unibitri_gram-processed'
    
]

# %% [markdown]
# # Definindo a função getTestMetrics

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

def getTestMetrics(y_test, y_pred, y_prob=None, full_metrics=True, print_charts=False):
    acc = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    precision_neg = precision_score(y_test, y_pred, pos_label=0)
    recall = recall_score(y_test, y_pred)
    recall_neg = recall_score(y_test, y_pred, pos_label=0)
    f1 = f1_score(y_test, y_pred)
    f1_neg = 2 * (precision_neg * recall_neg) / (precision_neg + recall_neg)

    # Calcular o ROC AUC apenas se y_prob não for None
    if y_prob is not None:
        roc_auc = roc_auc_score(y_test, y_prob)
    else:
        roc_auc = None  # ou algum valor indicativo, como 0.0
    
    return (acc, precision, precision_neg, recall, recall_neg, f1, f1_neg, roc_auc)

# %%
# Função de pré-processamento
def preprocess_data(df, experiment):
    if 'processed' in experiment:
        print("Pré-processamento ativado.")
        pro_texts = [preprocess(t) for t in df['text_content_anonymous']]
    else:
        print("Sem pré-processamento.")
        pro_texts = [processEmojisPunctuation(t.lower(), remove_punct=False) for t in df['text_content_anonymous']]
    return pro_texts

# %%
# Configuração do vetorizador com base no experimento
def configure_vectorizer(experiment):
    if 'tfidf' in experiment:
        if 'uni_gram' in experiment:
            return TfidfVectorizer(ngram_range=(1, 1))
        elif 'unibi_gram' in experiment:
            return TfidfVectorizer(ngram_range=(1, 2))
        elif 'unibitri_gram' in experiment:
            return TfidfVectorizer(ngram_range=(1, 3))
        else:
            return TfidfVectorizer()
    elif 'bow' in experiment:
        if 'uni_gram' in experiment:
            return CountVectorizer(binary=True, ngram_range=(1, 1))
        elif 'unibi_gram' in experiment:
            return CountVectorizer(binary=True, ngram_range=(1, 2))
        elif 'unibitri_gram' in experiment:
            return CountVectorizer(binary=True, ngram_range=(1, 3))
        else:
            return CountVectorizer(binary=True)

# %%
# Plotar a importância das features (limitado a 15 features mais importantes)
def plot_feature_importance(importances, feature_names, experiment, model_name, top_n=15):
    indices = np.argsort(importances)[::-1][:top_n]  # Selecionar as 15 mais importantes
    sorted_features = np.array(feature_names)[indices]
    sorted_importances = importances[indices]

    plt.figure(figsize=(10, 6))
    plt.bar(range(top_n), sorted_importances, align='center')
    plt.xticks(range(top_n), sorted_features, rotation=90, fontsize=8)
    plt.title(f"Top {top_n} Feature Importance ({experiment} - {model_name})")
    plt.xlabel("Features")
    plt.ylabel("Importance")
    plt.tight_layout()
    plt.show()

# Rodar para cada experimento
for experiment in experiments:
    start_time = time.time()

    try:
        print(f"Rodando experimento: {experiment}")

        # Removendo duplicatas e lidando com valores ausentes
        df = df.drop_duplicates(subset=['text_content_anonymous'])
        df['text_content_anonymous'] = df['text_content_anonymous'].fillna("")
        df['text_content_anonymous'] = df['text_content_anonymous'].astype(str)

        # Processar textos dependendo do experimento
        pro_texts = preprocess_data(df, experiment)

        # Configuração de vetorizador
        vectorizer = configure_vectorizer(experiment)
        X_texts = vectorizer.fit_transform(pro_texts)
        vocab_size_texts = X_texts.shape[1]

        # Printar o número de features do vetorizador
        print(f"[{experiment}] Número de features do vetorizador: {vocab_size_texts}")

        X_final = X_texts
        y = df['preconceito']

        # Dividir os dados em treino e teste
        X_train, X_test, y_train, y_test = train_test_split(
            X_final, y, test_size=0.2, stratify=y, random_state=42
        )

        # Definir os modelos a serem usados
        models = [
            LogisticRegression(), BernoulliNB(), MultinomialNB(), LinearSVC(dual=False),
            KNeighborsClassifier(), SGDClassifier(), RandomForestClassifier(),
            GradientBoostingClassifier(n_estimators=200),
            MLPClassifier(batch_size=64, max_iter=50, early_stopping=True, verbose=False)
        ]

        feature_names = list(vectorizer.get_feature_names_out()) 

        resultados = []

        # Avaliando os modelos
        for model in models:
            resultado_linha = dict()
            resultado_linha['model'] = model.__class__.__name__
            resultado_linha['vocab_size_text'] = vocab_size_texts

            # Medir o tempo de execução
            model_start_time = time.time()
            metodos_scoring = ['accuracy', 'precision', 'recall', 'f1', 'roc_auc']
            cv_results = cross_validate(model, X_train, y_train, cv=5, scoring=metodos_scoring, return_train_score=True)
            model_end_time = time.time()
            execution_time = model_end_time - model_start_time

            resultado_linha['execution_time'] = execution_time

            # Salvar as métricas
            for scoring in metodos_scoring:
                scores = cv_results[f'test_{scoring}']
                resultado_linha[f'{scoring}_avg'] = scores.mean()
                resultado_linha[f'{scoring}_std'] = scores.std()

            resultados.append(resultado_linha)

            # Plotar a importância das features (se aplicável)
            if hasattr(model, 'feature_importances_'):
                importances = model.feature_importances_
                plot_feature_importance(importances, feature_names, experiment, model.__class__.__name__)
            elif hasattr(model, 'coef_'):
                importances = np.abs(model.coef_[0])  # Para modelos lineares
                plot_feature_importance(importances, feature_names, experiment, model.__class__.__name__)

            # Printar informações durante a execução
            print(f"Model: {model.__class__.__name__} | Experiment: {experiment}")
            print(f"Vocab Size (Texts): {vocab_size_texts}")
            print(f"Execution Time: {execution_time:.2f} seconds")
            print("-" * 50)

        # Tempo total do experimento
        experiment_time = time.time() - start_time
        print(f"Tempo total do experimento '{experiment}': {experiment_time:.2f} seconds")

        # Criar um DataFrame com os resultados
        df_metrics = pd.DataFrame(resultados)
        df_metrics['total_time'] = experiment_time  # Adicionando o tempo total

        # Salvar os resultados em um arquivo CSV
        path_to_save = f"./resultados/01_09_25_Telegram_resultados_{experiment}.csv"
        df_metrics.to_csv(path_to_save, index=False)

        print(f"Resultados salvos em: {path_to_save}")

    except Exception as e:
        print(f"[{experiment}] Erro ao executar o experimento: {e}")
# Out:
# Rodando experimento: ml-tfidf-uni_gram
# Sem pré-processamento.
# [ml-tfidf-uni_gram] Número de features do vetorizador: 16362
# Model: LogisticRegression | Experiment: ml-tfidf-uni_gram
# Vocab Size (Texts): 16362
# Execution Time: 0.47 seconds
# --------------------------------------------------
# Model: BernoulliNB | Experiment: ml-tfidf-uni_gram
# Vocab Size (Texts): 16362
# Execution Time: 0.10 seconds
# --------------------------------------------------
# Model: MultinomialNB | Experiment: ml-tfidf-uni_gram
# Vocab Size (Texts): 16362
# Execution Time: 0.08 seconds
# --------------------------------------------------
# Model: LinearSVC | Experiment: ml-tfidf-uni_gram
# Vocab Size (Texts): 16362
# Execution Time: 0.19 seconds
# --------------------------------------------------
# Model: KNeighborsClassifier | Experiment: ml-tfidf-uni_gram
# Vocab Size (Texts): 16362
# Execution Time: 7.16 seconds
# --------------------------------------------------
# Model: SGDClassifier | Experiment: ml-tfidf-uni_gram
# Vocab Size (Texts): 16362
# Execution Time: 0.11 seconds
# --------------------------------------------------
# Model: RandomForestClassifier | Experiment: ml-tfidf-uni_gram
# Vocab Size (Texts): 16362
# Execution Time: 32.52 seconds
# --------------------------------------------------
# Model: GradientBoostingClassifier | Experiment: ml-tfidf-uni_gram
# Vocab Size (Texts): 16362
# Execution Time: 141.04 seconds
# --------------------------------------------------
# Model: MLPClassifier | Experiment: ml-tfidf-uni_gram
# Vocab Size (Texts): 16362
# Execution Time: 165.47 seconds
# --------------------------------------------------
# Tempo total do experimento 'ml-tfidf-uni_gram': 351.17 seconds
# Resultados salvos em: ./resultados/01_09_25_Telegram_resultados_ml-tfidf-uni_gram.csv
# Rodando experimento: ml-tfidf-uni_gram-processed
# Pré-processamento ativado.
# [ml-tfidf-uni_gram-processed] Número de features do vetorizador: 15209
# Model: LogisticRegression | Experiment: ml-tfidf-uni_gram-processed
# Vocab Size (Texts): 15209
# Execution Time: 1.01 seconds
# --------------------------------------------------
# Model: BernoulliNB | Experiment: ml-tfidf-uni_gram-processed
# Vocab Size (Texts): 15209
# Execution Time: 0.12 seconds
# --------------------------------------------------
# Model: MultinomialNB | Experiment: ml-tfidf-uni_gram-processed
# Vocab Size (Texts): 15209
# Execution Time: 0.09 seconds
# --------------------------------------------------
# Model: LinearSVC | Experiment: ml-tfidf-uni_gram-processed
# Vocab Size (Texts): 15209
# Execution Time: 0.28 seconds
# --------------------------------------------------
# Model: KNeighborsClassifier | Experiment: ml-tfidf-uni_gram-processed
# Vocab Size (Texts): 15209
# Execution Time: 3.94 seconds
# --------------------------------------------------
# Model: SGDClassifier | Experiment: ml-tfidf-uni_gram-processed
# Vocab Size (Texts): 15209
# Execution Time: 0.12 seconds
# --------------------------------------------------
# Model: RandomForestClassifier | Experiment: ml-tfidf-uni_gram-processed
# Vocab Size (Texts): 15209
# Execution Time: 37.54 seconds
# --------------------------------------------------
# Model: GradientBoostingClassifier | Experiment: ml-tfidf-uni_gram-processed
# Vocab Size (Texts): 15209
# Execution Time: 116.63 seconds
# --------------------------------------------------
# Model: MLPClassifier | Experiment: ml-tfidf-uni_gram-processed
# Vocab Size (Texts): 15209
# Execution Time: 126.66 seconds
# --------------------------------------------------
# Tempo total do experimento 'ml-tfidf-uni_gram-processed': 314.74 seconds
# Resultados salvos em: ./resultados/01_09_25_Telegram_resultados_ml-tfidf-uni_gram-processed.csv
# Rodando experimento: ml-tfidf-unibi_gram
# Sem pré-processamento.
# [ml-tfidf-unibi_gram] Número de features do vetorizador: 102288
# Model: LogisticRegression | Experiment: ml-tfidf-unibi_gram
# Vocab Size (Texts): 102288
# Execution Time: 2.14 seconds
# --------------------------------------------------
# Model: BernoulliNB | Experiment: ml-tfidf-unibi_gram
# Vocab Size (Texts): 102288
# Execution Time: 0.23 seconds
# --------------------------------------------------
# Model: MultinomialNB | Experiment: ml-tfidf-unibi_gram
# Vocab Size (Texts): 102288
# Execution Time: 0.14 seconds
# --------------------------------------------------
# Model: LinearSVC | Experiment: ml-tfidf-unibi_gram
# Vocab Size (Texts): 102288
# Execution Time: 0.41 seconds
# --------------------------------------------------
# Model: KNeighborsClassifier | Experiment: ml-tfidf-unibi_gram
# Vocab Size (Texts): 102288
# Execution Time: 22.44 seconds
# --------------------------------------------------
# Model: SGDClassifier | Experiment: ml-tfidf-unibi_gram
# Vocab Size (Texts): 102288
# Execution Time: 0.14 seconds
# --------------------------------------------------
# Model: RandomForestClassifier | Experiment: ml-tfidf-unibi_gram
# Vocab Size (Texts): 102288
# Execution Time: 106.99 seconds
# --------------------------------------------------
# Model: GradientBoostingClassifier | Experiment: ml-tfidf-unibi_gram
# Vocab Size (Texts): 102288
# Execution Time: 915.46 seconds
# --------------------------------------------------
# Model: MLPClassifier | Experiment: ml-tfidf-unibi_gram
# Vocab Size (Texts): 102288
# Execution Time: 1335.08 seconds
# --------------------------------------------------
# Tempo total do experimento 'ml-tfidf-unibi_gram': 2387.53 seconds
# Resultados salvos em: ./resultados/01_09_25_Telegram_resultados_ml-tfidf-unibi_gram.csv
# Rodando experimento: ml-tfidf-unibi_gram-processed
# Pré-processamento ativado.
# [ml-tfidf-unibi_gram-processed] Número de features do vetorizador: 84801
# Model: LogisticRegression | Experiment: ml-tfidf-unibi_gram-processed
# Vocab Size (Texts): 84801
# Execution Time: 2.74 seconds
# --------------------------------------------------
# Model: BernoulliNB | Experiment: ml-tfidf-unibi_gram-processed
# Vocab Size (Texts): 84801
# Execution Time: 0.26 seconds
# --------------------------------------------------
# Model: MultinomialNB | Experiment: ml-tfidf-unibi_gram-processed
# Vocab Size (Texts): 84801
# Execution Time: 0.15 seconds
# --------------------------------------------------
# Model: LinearSVC | Experiment: ml-tfidf-unibi_gram-processed
# Vocab Size (Texts): 84801
# Execution Time: 0.42 seconds
# --------------------------------------------------
# Model: KNeighborsClassifier | Experiment: ml-tfidf-unibi_gram-processed
# Vocab Size (Texts): 84801
# Execution Time: 13.06 seconds
# --------------------------------------------------
# Model: SGDClassifier | Experiment: ml-tfidf-unibi_gram-processed
# Vocab Size (Texts): 84801
# Execution Time: 0.14 seconds
# --------------------------------------------------
# Model: RandomForestClassifier | Experiment: ml-tfidf-unibi_gram-processed
# Vocab Size (Texts): 84801
# Execution Time: 123.48 seconds
# --------------------------------------------------
# Model: GradientBoostingClassifier | Experiment: ml-tfidf-unibi_gram-processed
# Vocab Size (Texts): 84801
# Execution Time: 545.22 seconds
# --------------------------------------------------
# Model: MLPClassifier | Experiment: ml-tfidf-unibi_gram-processed
# Vocab Size (Texts): 84801
# Execution Time: 612.26 seconds
# --------------------------------------------------
# Tempo total do experimento 'ml-tfidf-unibi_gram-processed': 1327.73 seconds
# Resultados salvos em: ./resultados/01_09_25_Telegram_resultados_ml-tfidf-unibi_gram-processed.csv
# Rodando experimento: ml-tfidf-unibitri_gram
# Sem pré-processamento.
# [ml-tfidf-unibitri_gram] Número de features do vetorizador: 222554
# Model: LogisticRegression | Experiment: ml-tfidf-unibitri_gram
# Vocab Size (Texts): 222554
# Execution Time: 4.49 seconds
# --------------------------------------------------
# Model: BernoulliNB | Experiment: ml-tfidf-unibitri_gram
# Vocab Size (Texts): 222554
# Execution Time: 0.43 seconds
# --------------------------------------------------
# Model: MultinomialNB | Experiment: ml-tfidf-unibitri_gram
# Vocab Size (Texts): 222554
# Execution Time: 0.19 seconds
# --------------------------------------------------
# Model: LinearSVC | Experiment: ml-tfidf-unibitri_gram
# Vocab Size (Texts): 222554
# Execution Time: 0.74 seconds
# --------------------------------------------------
# Model: KNeighborsClassifier | Experiment: ml-tfidf-unibitri_gram
# Vocab Size (Texts): 222554
# Execution Time: 48.40 seconds
# --------------------------------------------------
# Model: SGDClassifier | Experiment: ml-tfidf-unibitri_gram
# Vocab Size (Texts): 222554
# Execution Time: 0.21 seconds
# --------------------------------------------------
# Model: RandomForestClassifier | Experiment: ml-tfidf-unibitri_gram
# Vocab Size (Texts): 222554
# Execution Time: 185.45 seconds
# --------------------------------------------------
# Model: GradientBoostingClassifier | Experiment: ml-tfidf-unibitri_gram
# Vocab Size (Texts): 222554
# Execution Time: 1430.90 seconds
# --------------------------------------------------
# Model: MLPClassifier | Experiment: ml-tfidf-unibitri_gram
# Vocab Size (Texts): 222554
# Execution Time: 2405.19 seconds
# --------------------------------------------------
# Tempo total do experimento 'ml-tfidf-unibitri_gram': 4081.31 seconds
# Resultados salvos em: ./resultados/01_09_25_Telegram_resultados_ml-tfidf-unibitri_gram.csv
# Rodando experimento: ml-tfidf-unibitri_gram-processed
# Pré-processamento ativado.
# [ml-tfidf-unibitri_gram-processed] Número de features do vetorizador: 164387
# Model: LogisticRegression | Experiment: ml-tfidf-unibitri_gram-processed
# Vocab Size (Texts): 164387
# Execution Time: 3.38 seconds
# --------------------------------------------------
# Model: BernoulliNB | Experiment: ml-tfidf-unibitri_gram-processed
# Vocab Size (Texts): 164387
# Execution Time: 0.27 seconds
# --------------------------------------------------
# Model: MultinomialNB | Experiment: ml-tfidf-unibitri_gram-processed
# Vocab Size (Texts): 164387
# Execution Time: 0.14 seconds
# --------------------------------------------------
# Model: LinearSVC | Experiment: ml-tfidf-unibitri_gram-processed
# Vocab Size (Texts): 164387
# Execution Time: 0.41 seconds
# --------------------------------------------------
# Model: KNeighborsClassifier | Experiment: ml-tfidf-unibitri_gram-processed
# Vocab Size (Texts): 164387
# Execution Time: 22.43 seconds
# --------------------------------------------------
# Model: SGDClassifier | Experiment: ml-tfidf-unibitri_gram-processed
# Vocab Size (Texts): 164387
# Execution Time: 0.17 seconds
# --------------------------------------------------
# Model: RandomForestClassifier | Experiment: ml-tfidf-unibitri_gram-processed
# Vocab Size (Texts): 164387
# Execution Time: 146.39 seconds
# --------------------------------------------------
# Model: GradientBoostingClassifier | Experiment: ml-tfidf-unibitri_gram-processed
# Vocab Size (Texts): 164387
# Execution Time: 944.49 seconds
# --------------------------------------------------
# Model: MLPClassifier | Experiment: ml-tfidf-unibitri_gram-processed
# Vocab Size (Texts): 164387
# Execution Time: 1159.38 seconds
# --------------------------------------------------
# Tempo total do experimento 'ml-tfidf-unibitri_gram-processed': 2297.24 seconds
# Resultados salvos em: ./resultados/01_09_25_Telegram_resultados_ml-tfidf-unibitri_gram-processed.csv
# Rodando experimento: ml-bow-uni_gram
# Sem pré-processamento.
# [ml-bow-uni_gram] Número de features do vetorizador: 16362
# Model: LogisticRegression | Experiment: ml-bow-uni_gram
# Vocab Size (Texts): 16362
# Execution Time: 0.78 seconds
# --------------------------------------------------
# Model: BernoulliNB | Experiment: ml-bow-uni_gram
# Vocab Size (Texts): 16362
# Execution Time: 0.09 seconds
# --------------------------------------------------
# Model: MultinomialNB | Experiment: ml-bow-uni_gram
# Vocab Size (Texts): 16362
# Execution Time: 0.07 seconds
# --------------------------------------------------
# Model: LinearSVC | Experiment: ml-bow-uni_gram
# Vocab Size (Texts): 16362
# Execution Time: 2.10 seconds
# --------------------------------------------------
# Model: KNeighborsClassifier | Experiment: ml-bow-uni_gram
# Vocab Size (Texts): 16362
# Execution Time: 1.84 seconds
# --------------------------------------------------
# Model: SGDClassifier | Experiment: ml-bow-uni_gram
# Vocab Size (Texts): 16362
# Execution Time: 0.07 seconds
# --------------------------------------------------
# Model: RandomForestClassifier | Experiment: ml-bow-uni_gram
# Vocab Size (Texts): 16362
# Execution Time: 33.32 seconds
# --------------------------------------------------
# Model: GradientBoostingClassifier | Experiment: ml-bow-uni_gram
# Vocab Size (Texts): 16362
# Execution Time: 81.62 seconds
# --------------------------------------------------
# Model: MLPClassifier | Experiment: ml-bow-uni_gram
# Vocab Size (Texts): 16362
# Execution Time: 120.98 seconds
# --------------------------------------------------
# Tempo total do experimento 'ml-bow-uni_gram': 244.66 seconds
# Resultados salvos em: ./resultados/01_09_25_Telegram_resultados_ml-bow-uni_gram.csv
# Rodando experimento: ml-bow-uni_gram-processed
# Pré-processamento ativado.
# [ml-bow-uni_gram-processed] Número de features do vetorizador: 15209
# Model: LogisticRegression | Experiment: ml-bow-uni_gram-processed
# Vocab Size (Texts): 15209
# Execution Time: 0.65 seconds
# --------------------------------------------------
# Model: BernoulliNB | Experiment: ml-bow-uni_gram-processed
# Vocab Size (Texts): 15209
# Execution Time: 0.07 seconds
# --------------------------------------------------
# Model: MultinomialNB | Experiment: ml-bow-uni_gram-processed
# Vocab Size (Texts): 15209
# Execution Time: 0.06 seconds
# --------------------------------------------------
# Model: LinearSVC | Experiment: ml-bow-uni_gram-processed
# Vocab Size (Texts): 15209
# Execution Time: 1.66 seconds
# --------------------------------------------------
# Model: KNeighborsClassifier | Experiment: ml-bow-uni_gram-processed
# Vocab Size (Texts): 15209
# Execution Time: 1.33 seconds
# --------------------------------------------------
# Model: SGDClassifier | Experiment: ml-bow-uni_gram-processed
# Vocab Size (Texts): 15209
# Execution Time: 0.12 seconds
# --------------------------------------------------
# Model: RandomForestClassifier | Experiment: ml-bow-uni_gram-processed
# Vocab Size (Texts): 15209
# Execution Time: 35.31 seconds
# --------------------------------------------------
# Model: GradientBoostingClassifier | Experiment: ml-bow-uni_gram-processed
# Vocab Size (Texts): 15209
# Execution Time: 75.53 seconds
# --------------------------------------------------
# Model: MLPClassifier | Experiment: ml-bow-uni_gram-processed
# Vocab Size (Texts): 15209
# Execution Time: 89.99 seconds
# --------------------------------------------------
# Tempo total do experimento 'ml-bow-uni_gram-processed': 223.33 seconds
# Resultados salvos em: ./resultados/01_09_25_Telegram_resultados_ml-bow-uni_gram-processed.csv
# Rodando experimento: ml-bow-unibi_gram
# Sem pré-processamento.
# [ml-bow-unibi_gram] Número de features do vetorizador: 102288
# Model: LogisticRegression | Experiment: ml-bow-unibi_gram
# Vocab Size (Texts): 102288
# Execution Time: 2.52 seconds
# --------------------------------------------------
# Model: BernoulliNB | Experiment: ml-bow-unibi_gram
# Vocab Size (Texts): 102288
# Execution Time: 0.20 seconds
# --------------------------------------------------
# Model: MultinomialNB | Experiment: ml-bow-unibi_gram
# Vocab Size (Texts): 102288
# Execution Time: 0.12 seconds
# --------------------------------------------------
# Model: LinearSVC | Experiment: ml-bow-unibi_gram
# Vocab Size (Texts): 102288
# Execution Time: 7.92 seconds
# --------------------------------------------------
# Model: KNeighborsClassifier | Experiment: ml-bow-unibi_gram
# Vocab Size (Texts): 102288
# Execution Time: 2.00 seconds
# --------------------------------------------------
# Model: SGDClassifier | Experiment: ml-bow-unibi_gram
# Vocab Size (Texts): 102288
# Execution Time: 0.13 seconds
# --------------------------------------------------
# Model: RandomForestClassifier | Experiment: ml-bow-unibi_gram
# Vocab Size (Texts): 102288
# Execution Time: 94.07 seconds
# --------------------------------------------------
# Model: GradientBoostingClassifier | Experiment: ml-bow-unibi_gram
# Vocab Size (Texts): 102288
# Execution Time: 527.67 seconds
# --------------------------------------------------
# Model: MLPClassifier | Experiment: ml-bow-unibi_gram
# Vocab Size (Texts): 102288
# Execution Time: 944.45 seconds
# --------------------------------------------------
# Tempo total do experimento 'ml-bow-unibi_gram': 1583.13 seconds
# Resultados salvos em: ./resultados/01_09_25_Telegram_resultados_ml-bow-unibi_gram.csv
# Rodando experimento: ml-bow-unibi_gram-processed
# Pré-processamento ativado.
# [ml-bow-unibi_gram-processed] Número de features do vetorizador: 84801
# Model: LogisticRegression | Experiment: ml-bow-unibi_gram-processed
# Vocab Size (Texts): 84801
# Execution Time: 2.50 seconds
# --------------------------------------------------
# Model: BernoulliNB | Experiment: ml-bow-unibi_gram-processed
# Vocab Size (Texts): 84801
# Execution Time: 0.21 seconds
# --------------------------------------------------
# Model: MultinomialNB | Experiment: ml-bow-unibi_gram-processed
# Vocab Size (Texts): 84801
# Execution Time: 0.12 seconds
# --------------------------------------------------
# Model: LinearSVC | Experiment: ml-bow-unibi_gram-processed
# Vocab Size (Texts): 84801
# Execution Time: 6.32 seconds
# --------------------------------------------------
# Model: KNeighborsClassifier | Experiment: ml-bow-unibi_gram-processed
# Vocab Size (Texts): 84801
# Execution Time: 1.59 seconds
# --------------------------------------------------
# Model: SGDClassifier | Experiment: ml-bow-unibi_gram-processed
# Vocab Size (Texts): 84801
# Execution Time: 0.10 seconds
# --------------------------------------------------
# Model: RandomForestClassifier | Experiment: ml-bow-unibi_gram-processed
# Vocab Size (Texts): 84801
# Execution Time: 100.49 seconds
# --------------------------------------------------
# Model: GradientBoostingClassifier | Experiment: ml-bow-unibi_gram-processed
# Vocab Size (Texts): 84801
# Execution Time: 420.42 seconds
# --------------------------------------------------
# Model: MLPClassifier | Experiment: ml-bow-unibi_gram-processed
# Vocab Size (Texts): 84801
# Execution Time: 994.80 seconds
# --------------------------------------------------
# Tempo total do experimento 'ml-bow-unibi_gram-processed': 1549.50 seconds
# Resultados salvos em: ./resultados/01_09_25_Telegram_resultados_ml-bow-unibi_gram-processed.csv
# Rodando experimento: ml-bow-unibitri_gram
# Sem pré-processamento.
# [ml-bow-unibitri_gram] Número de features do vetorizador: 222554
# Model: LogisticRegression | Experiment: ml-bow-unibitri_gram
# Vocab Size (Texts): 222554
# Execution Time: 7.24 seconds
# --------------------------------------------------
# Model: BernoulliNB | Experiment: ml-bow-unibitri_gram
# Vocab Size (Texts): 222554
# Execution Time: 0.35 seconds
# --------------------------------------------------
# Model: MultinomialNB | Experiment: ml-bow-unibitri_gram
# Vocab Size (Texts): 222554
# Execution Time: 0.19 seconds
# --------------------------------------------------
# Model: LinearSVC | Experiment: ml-bow-unibitri_gram
# Vocab Size (Texts): 222554
# Execution Time: 30.76 seconds
# --------------------------------------------------
# Model: KNeighborsClassifier | Experiment: ml-bow-unibitri_gram
# Vocab Size (Texts): 222554
# Execution Time: 2.43 seconds
# --------------------------------------------------
# Model: SGDClassifier | Experiment: ml-bow-unibitri_gram
# Vocab Size (Texts): 222554
# Execution Time: 0.17 seconds
# --------------------------------------------------
# Model: RandomForestClassifier | Experiment: ml-bow-unibitri_gram
# Vocab Size (Texts): 222554
# Execution Time: 169.98 seconds
# --------------------------------------------------
# Model: GradientBoostingClassifier | Experiment: ml-bow-unibitri_gram
# Vocab Size (Texts): 222554
# Execution Time: 1220.59 seconds
# --------------------------------------------------
# Model: MLPClassifier | Experiment: ml-bow-unibitri_gram
# Vocab Size (Texts): 222554
# Execution Time: 1561.63 seconds
# --------------------------------------------------
# Tempo total do experimento 'ml-bow-unibitri_gram': 2998.07 seconds
# Resultados salvos em: ./resultados/01_09_25_Telegram_resultados_ml-bow-unibitri_gram.csv
# Rodando experimento: ml-bow-unibitri_gram-processed
# Pré-processamento ativado.
# [ml-bow-unibitri_gram-processed] Número de features do vetorizador: 164387
# Model: LogisticRegression | Experiment: ml-bow-unibitri_gram-processed
# Vocab Size (Texts): 164387
# Execution Time: 3.49 seconds
# --------------------------------------------------
# Model: BernoulliNB | Experiment: ml-bow-unibitri_gram-processed
# Vocab Size (Texts): 164387
# Execution Time: 0.25 seconds
# --------------------------------------------------
# Model: MultinomialNB | Experiment: ml-bow-unibitri_gram-processed
# Vocab Size (Texts): 164387
# Execution Time: 0.13 seconds
# --------------------------------------------------
# Model: LinearSVC | Experiment: ml-bow-unibitri_gram-processed
# Vocab Size (Texts): 164387
# Execution Time: 12.41 seconds
# --------------------------------------------------
# Model: KNeighborsClassifier | Experiment: ml-bow-unibitri_gram-processed
# Vocab Size (Texts): 164387
# Execution Time: 1.56 seconds
# --------------------------------------------------
# Model: SGDClassifier | Experiment: ml-bow-unibitri_gram-processed
# Vocab Size (Texts): 164387
# Execution Time: 0.14 seconds
# --------------------------------------------------
# Model: RandomForestClassifier | Experiment: ml-bow-unibitri_gram-processed
# Vocab Size (Texts): 164387
# Execution Time: 198.63 seconds
# --------------------------------------------------
# Model: GradientBoostingClassifier | Experiment: ml-bow-unibitri_gram-processed
# Vocab Size (Texts): 164387
# Execution Time: 1708.77 seconds
# --------------------------------------------------
# Model: MLPClassifier | Experiment: ml-bow-unibitri_gram-processed
# Vocab Size (Texts): 164387
# Execution Time: 1506.08 seconds
# --------------------------------------------------
# Tempo total do experimento 'ml-bow-unibitri_gram-processed': 3453.14 seconds
# Resultados salvos em: ./resultados/01_09_25_Telegram_resultados_ml-bow-unibitri_gram-processed.csv

# %% [markdown]
# ## Curva de Aprendizagem do melhor modelo

# %%
# === Escolher experimento ===
experiment = 'ml-bow-uni_gram'
print(f"Rodando experimento: {experiment}")

# --- Pré-processar textos ---
df = df.drop_duplicates(subset=['text_content_anonymous'])
df['text_content_anonymous'] = df['text_content_anonymous'].fillna("").astype(str)
pro_texts = preprocess_data(df, experiment)

# --- Vetorizador TF-IDF unigram, bigram ---
vectorizer = configure_vectorizer(experiment)
X_texts = vectorizer.fit_transform(pro_texts)
vocab_size_texts = X_texts.shape[1]

print(f"[{experiment}] Número de features do vetorizador: {vocab_size_texts}")

X_final = X_texts
y = df['preconceito']

# --- Divisão treino/teste ---
X_train, X_test, y_train, y_test = train_test_split(
    X_final, y, test_size=0.2, stratify=y, random_state=42
)

# --- Modelo Gradient Boosting ---
model = GradientBoostingClassifier(n_estimators=200)

# --- Treinamento ---
model.fit(X_train, y_train)

# --- Predições ---
y_pred = model.predict(X_test)
y_prob = model.predict_proba(X_test)[:, 1]

# --- Métricas ---
acc, prec_pos, prec_neg, rec_pos, rec_neg, f1_pos, f1_neg, roc_auc = getTestMetrics(
    y_test, y_pred, y_prob
)

print("\n Resultados - Gradient Boosting (BoW unigram)")
print(f"Acurácia:  {acc:.3f}")
print(f"Precisão:  {prec_pos:.3f}")
print(f"Revocação: {rec_pos:.3f}")
print(f"F1:        {f1_pos:.3f}")
print(f"ROC AUC:   {roc_auc:.3f}")


# --- Matriz de confusão ---
cm = confusion_matrix(y_test, y_pred)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["0", "1"])
fig, ax = plt.subplots(figsize=(5, 4))
disp.plot(cmap="Blues", values_format="d", ax=ax)

# Renomear eixos
ax.set_xlabel("Label Predita")
ax.set_ylabel("Label Verdadeira")

for spine in ax.spines.values():
    spine.set_visible(False)  # Remove bordas externas

ax.grid(False)                # Remove linhas de grade
plt.title(" Matrix de Confusão — Gradient Boosting (BoW unigrama)")

plt.savefig("./resultados/matriz_confusao_gradient_boosting_unigram_telegram.png", dpi=300, bbox_inches="tight")
plt.show()

# === Curva de Aprendizado ===

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
train_sizes, train_scores, val_scores = learning_curve(
    model, X_final, y,
    cv=cv, scoring="f1", n_jobs=-1,
    train_sizes=np.linspace(0.1, 1.0, 10)
)

train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
val_mean = np.mean(val_scores, axis=1)
val_std = np.std(val_scores, axis=1)

plt.figure(figsize=(10, 6))
plt.title("Curva de Aprendizagem - Gradient Boosting (BoW unigrama)")
plt.plot(train_sizes, train_mean, color="blue", label="Treino")
plt.plot(train_sizes, val_mean, color="orange", label="Validação")
plt.xlabel("Tamanho do conjunto de treinamento")
plt.ylabel("F1 Score")
plt.legend(loc="best")
plt.grid(True)
plt.show()
# Out:
# Rodando experimento: ml-bow-uni_gram
# Sem pré-processamento.
# [ml-bow-uni_gram] Número de features do vetorizador: 16362
#
#  Resultados - Gradient Boosting (BoW unigram)
# Acurácia:  0.862
# Precisão:  0.922
# Revocação: 0.790
# F1:        0.851
# ROC AUC:   0.922
# d:\Arquivos_Acer\Documents\UFC\PrejudicePT-br-main\ambiente_prejudice\lib\site-packages\sklearn\model_selection\_validation.py:516: FitFailedWarning:
# 25 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 25 fits failed with the following error:
# Traceback (most recent call last):
#   File "d:\Arquivos_Acer\Documents\UFC\PrejudicePT-br-main\ambiente_prejudice\lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "d:\Arquivos_Acer\Documents\UFC\PrejudicePT-br-main\ambiente_prejudice\lib\site-packages\sklearn\base.py", line 1365, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "d:\Arquivos_Acer\Documents\UFC\PrejudicePT-br-main\ambiente_prejudice\lib\site-packages\sklearn\ensemble\_gb.py", line 669, in fit
#     y = self._encode_y(y=y, sample_weight=None)
#   File "d:\Arquivos_Acer\Documents\UFC\PrejudicePT-br-main\ambiente_prejudice\lib\site-packages\sklearn\ensemble\_gb.py", line 1536, in _encode_y
#     raise ValueError(
# ValueError: y contains 1 class after sample_weight trimmed classes with zero weights, while a minimum of 2 classes are required.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
