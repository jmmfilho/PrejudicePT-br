# %%
import pandas as pd
import requests
import json
import tiktoken
import time
import re
import glob # Para encontrar arquivos em um diretório
import numpy as np
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, accuracy_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

API_KEY = ""

# %%
# Configuração da API
HEADERS = {"Authorization": f"Bearer {API_KEY }", "Content-Type": "application/json"}
url = "https://api.openai.com/v1/chat/completions"
MODEL = "gpt-4o-mini"

LIMITE_MODELO = 8000
EST_SAIDA_POR_ITEM = 5
TEMPERATURE = 0.0
TOP_P = 1.0

# %%
# === CONFIGURAÇÕES GERAIS ===
PROMPT_FIXO = "Classifique os textos a seguir em 0 (não preconceito) ou 1 (preconceito). Não precisa de explicação, apenas rotule.\n"


# Inicializa o codificador
enc = tiktoken.encoding_for_model(MODEL)
TOKENS_PROMPT_FIXO = len(enc.encode(PROMPT_FIXO))


# === FUNÇÕES AUXILIARES ===
def contar_tokens_string(s: str) -> int:
    return len(enc.encode(s or ""))


def estimar_tokens_lote(itens):
    """Estima tokens de um lote."""
    total = TOKENS_PROMPT_FIXO
    for i, (_, t) in enumerate(itens):
        total += contar_tokens_string(f"{i}: {t}")
    total += len(itens) * EST_SAIDA_POR_ITEM
    return total


def split_em_lotes(df_textos, limite=LIMITE_MODELO):
    """Divide DataFrame em lotes respeitando o limite de tokens."""
    lotes, lote = [], []
    for _, row in df_textos.iterrows():
        id_val = str(row["id"])
        texto = str(row["text_content_anonymous"])
        if estimar_tokens_lote(lote + [(id_val, texto)]) <= limite:
            lote.append((id_val, texto))
        else:
            if lote:
                lotes.append(lote)
            lote = [(id_val, texto)]
            # Trunca texto se mesmo isolado for muito grande
            if estimar_tokens_lote(lote) > limite:
                trunc = enc.decode(enc.encode(texto)[:2048])
                lote = [(id_val, trunc)]
    if lote:
        lotes.append(lote)
    return lotes


def extrair_json_da_resposta(texto_resposta: str):
    """Extrai JSON da resposta do modelo."""
    try:
        start, end = texto_resposta.find("{"), texto_resposta.rfind("}")
        if start != -1 and end != -1 and end > start:
            return json.loads(texto_resposta[start:end + 1])
        return json.loads(texto_resposta)
    except Exception:
        return None


def enviar_lote(lote, prompt_base, max_tokens=1024):
    """Envia um lote para a API OpenAI."""
    prompt = prompt_base + "".join(f"\n{i}: {t}" for i, (_, t) in enumerate(lote))
    prompt += '\n\nResponda no formato JSON, onde cada índice corresponde ao rótulo. Exemplo: {"0": 0, "1": 1}\n'

    body = {
        "model": MODEL,
        "messages": [{"role": "user", "content": prompt}],
        "max_tokens": max_tokens,
        "temperature": TEMPERATURE,
        "top_p": TOP_P,
        "frequency_penalty": 0,
        "presence_penalty": 0
    }

    return requests.post(
        "https://api.openai.com/v1/chat/completions",
        headers=HEADERS,
        data=json.dumps(body),
        timeout=120
    )


# === FUNÇÃO PRINCIPAL ===
def processar_arquivo(csv_entrada, csv_saida, prompt_base, log_nome):
    """Processa um arquivo CSV em lotes."""
    inicio = time.time()
    print(f"\nProcessando {csv_entrada} -> {csv_saida}")

    df = pd.read_csv(csv_entrada, dtype=str, encoding="utf-8", keep_default_na=False)
    df = df[df["text_content_anonymous"].str.strip() != ""].reset_index(drop=True)
    lotes = split_em_lotes(df)
    resultados = []

    # contadores de tokens
    total_prompt_tokens = total_completion_tokens = total_total_tokens = 0

    for i, lote in enumerate(lotes, start=1):
        print(f"Lote {i}/{len(lotes)} - {len(lote)} textos")
        max_tokens_saida = max(200, len(lote) * 8)

        try:
            resp = enviar_lote(lote, prompt_base, max_tokens=max_tokens_saida)
        except Exception as e:
            print("Erro na requisição HTTP:", e)
            resultados += [[id_val, texto, "ERRO_REQ"] for id_val, texto in lote]
            continue

        if resp.status_code != 200:
            print(f"Erro HTTP {resp.status_code}")
            resultados += [[id_val, texto, f"HTTP_{resp.status_code}"] for id_val, texto in lote]
            continue

        saida = resp.json()
        saida_texto = saida["choices"][0]["message"]["content"]
        rotulos_dict = extrair_json_da_resposta(saida_texto)

        usage = saida.get("usage", {})
        total_prompt_tokens += usage.get("prompt_tokens", 0)
        total_completion_tokens += usage.get("completion_tokens", 0)
        total_total_tokens += usage.get("total_tokens", 0)

        if not rotulos_dict:
            resultados += [[id_val, texto, "ERRO_PARSE"] for id_val, texto in lote]
            continue

        for idx, (id_val, texto) in enumerate(lote):
            rot = str(rotulos_dict.get(str(idx), "")).strip()
            if rot not in ("0", "1"):
                rot = "ERRO_VAL" if rot else "ERRO_NA_CHAVE"
            resultados.append([id_val, texto, rot])

        time.sleep(0.4)

    # salva resultados
    pd.DataFrame(resultados, columns=["id", "text_content_anonymous", "rotulo_modelo"]).to_csv(csv_saida, index=False, encoding="utf-8")
    print("Arquivo salvo em", csv_saida)

    duracao_min = (time.time() - inicio) / 60
    with open(log_nome, "a", encoding="utf-8") as f:
        f.write(
            f"{csv_entrada} -> {csv_saida} | Tempo: {duracao_min:.2f} min | "
            f"Prompt tokens: {total_prompt_tokens} | Saída tokens: {total_completion_tokens} | Total tokens: {total_total_tokens}\n"
        )

    print(f"Tempo total: {duracao_min:.2f} min | Tokens total: {total_total_tokens}")

# %%
# === EXECUÇÃO ZERO-SHOT ===
inicio_total = time.time()
for i in range(1, 13):
    entrada = f"../datasets/wpp/parte_{i}_wpp.csv"
    saida = f"./resultados/wpp/zero_shot_parte_{i}.csv"
    processar_arquivo(entrada, saida, PROMPT_FIXO, "./resultados/wpp/zeroShot_log_processamento_wpp.txt")
total_minutos = (time.time() - inicio_total) / 60
with open("./resultados/wpp/zeroShot_tempo_execucao_wpp.txt", "a", encoding="utf-8") as f:
    f.write(f"\nTempo total de execução: {total_minutos:.2f} minutos\n")
# Out:
# Processando ../datasets/wpp/parte_1_wpp.csv -> ./resultados/wpp/zero_shot_parte_1.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/zero_shot_parte_1.csv
# Tempo total: 0.15 min | Tokens total: 4722
#
# Processando ../datasets/wpp/parte_2_wpp.csv -> ./resultados/wpp/zero_shot_parte_2.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/zero_shot_parte_2.csv
# Tempo total: 0.16 min | Tokens total: 4088
#
# Processando ../datasets/wpp/parte_3_wpp.csv -> ./resultados/wpp/zero_shot_parte_3.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/zero_shot_parte_3.csv
# Tempo total: 0.14 min | Tokens total: 4117
#
# Processando ../datasets/wpp/parte_4_wpp.csv -> ./resultados/wpp/zero_shot_parte_4.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/zero_shot_parte_4.csv
# Tempo total: 0.18 min | Tokens total: 3533
#
# Processando ../datasets/wpp/parte_5_wpp.csv -> ./resultados/wpp/zero_shot_parte_5.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/zero_shot_parte_5.csv
# Tempo total: 0.15 min | Tokens total: 3610
#
# Processando ../datasets/wpp/parte_6_wpp.csv -> ./resultados/wpp/zero_shot_parte_6.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/zero_shot_parte_6.csv
# Tempo total: 0.18 min | Tokens total: 3725
#
# Processando ../datasets/wpp/parte_7_wpp.csv -> ./resultados/wpp/zero_shot_parte_7.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/zero_shot_parte_7.csv
# Tempo total: 0.12 min | Tokens total: 3585
#
# Processando ../datasets/wpp/parte_8_wpp.csv -> ./resultados/wpp/zero_shot_parte_8.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/zero_shot_parte_8.csv
# Tempo total: 0.17 min | Tokens total: 4757
#
# Processando ../datasets/wpp/parte_9_wpp.csv -> ./resultados/wpp/zero_shot_parte_9.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/zero_shot_parte_9.csv
# Tempo total: 0.11 min | Tokens total: 3569
#
# Processando ../datasets/wpp/parte_10_wpp.csv -> ./resultados/wpp/zero_shot_parte_10.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/zero_shot_parte_10.csv
# Tempo total: 0.13 min | Tokens total: 4478
#
# Processando ../datasets/wpp/parte_11_wpp.csv -> ./resultados/wpp/zero_shot_parte_11.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/zero_shot_parte_11.csv
# Tempo total: 0.17 min | Tokens total: 4289
#
# Processando ../datasets/wpp/parte_12_wpp.csv -> ./resultados/wpp/zero_shot_parte_12.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/zero_shot_parte_12.csv
# Tempo total: 0.14 min | Tokens total: 4181

# %%
# === EXECUÇÃO FEW-SHOT ===
with open("../datasets/wpp/few_shot.txt", "r", encoding="utf-8") as f:
    PROMPT_FEW = f.read()

inicio_total = time.time()
for i in range(1, 13):
    entrada = f"../datasets/wpp/parte_{i}_wpp.csv"
    saida = f"./resultados/wpp/few_shot_parte_{i}.csv"
    processar_arquivo(entrada, saida, PROMPT_FEW, "./resultados/wpp/fewShot_log_processamento_wpp.txt")
total_minutos = (time.time() - inicio_total) / 60
with open("./resultados/wpp/fewShot_tempo_execucao_wpp.txt", "a", encoding="utf-8") as f:
    f.write(f"\nTempo total de execução: {total_minutos:.2f} minutos\n")
# Out:
# Processando ../datasets/wpp/parte_1_wpp.csv -> ./resultados/wpp/few_shot_parte_1.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/few_shot_parte_1.csv
# Tempo total: 0.10 min | Tokens total: 5536
#
# Processando ../datasets/wpp/parte_2_wpp.csv -> ./resultados/wpp/few_shot_parte_2.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/few_shot_parte_2.csv
# Tempo total: 0.11 min | Tokens total: 4902
#
# Processando ../datasets/wpp/parte_3_wpp.csv -> ./resultados/wpp/few_shot_parte_3.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/few_shot_parte_3.csv
# Tempo total: 0.13 min | Tokens total: 4931
#
# Processando ../datasets/wpp/parte_4_wpp.csv -> ./resultados/wpp/few_shot_parte_4.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/few_shot_parte_4.csv
# Tempo total: 0.11 min | Tokens total: 4347
#
# Processando ../datasets/wpp/parte_5_wpp.csv -> ./resultados/wpp/few_shot_parte_5.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/few_shot_parte_5.csv
# Tempo total: 0.11 min | Tokens total: 4424
#
# Processando ../datasets/wpp/parte_6_wpp.csv -> ./resultados/wpp/few_shot_parte_6.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/few_shot_parte_6.csv
# Tempo total: 0.10 min | Tokens total: 4539
#
# Processando ../datasets/wpp/parte_7_wpp.csv -> ./resultados/wpp/few_shot_parte_7.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/few_shot_parte_7.csv
# Tempo total: 0.10 min | Tokens total: 4399
#
# Processando ../datasets/wpp/parte_8_wpp.csv -> ./resultados/wpp/few_shot_parte_8.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/few_shot_parte_8.csv
# Tempo total: 0.11 min | Tokens total: 5571
#
# Processando ../datasets/wpp/parte_9_wpp.csv -> ./resultados/wpp/few_shot_parte_9.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/few_shot_parte_9.csv
# Tempo total: 0.10 min | Tokens total: 4383
#
# Processando ../datasets/wpp/parte_10_wpp.csv -> ./resultados/wpp/few_shot_parte_10.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/few_shot_parte_10.csv
# Tempo total: 0.11 min | Tokens total: 5292
#
# Processando ../datasets/wpp/parte_11_wpp.csv -> ./resultados/wpp/few_shot_parte_11.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/few_shot_parte_11.csv
# Tempo total: 0.13 min | Tokens total: 5103
#
# Processando ../datasets/wpp/parte_12_wpp.csv -> ./resultados/wpp/few_shot_parte_12.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/few_shot_parte_12.csv
# Tempo total: 0.11 min | Tokens total: 4995

# %%
# === EXECUÇÃO Role Prompting + DIC (Especialista em discurso preconceituoso) ===
with open("../datasets/prompt_role_dicionario.txt", "r", encoding="utf-8") as f:
    PROMPT_ROLE = f.read()

inicio_total = time.time()
for i in range(1, 13):
    entrada = f"../datasets/wpp/parte_{i}_wpp.csv"
    saida = f"./resultados/wpp/prompt_role_dicionario_parte_{i}.csv"
    processar_arquivo(entrada, saida, PROMPT_ROLE, "./resultados/wpp/prompt_dicionario_log_processamento.txt")
total_minutos = (time.time() - inicio_total) / 60
with open("./resultados/wpp/prompt_role_dicionario_tempo_execucao_wpp.txt", "a", encoding="utf-8") as f:
    f.write(f"\nTempo total de execução: {total_minutos:.2f} minutos\n")
# Out:
# Processando ../datasets/wpp/parte_1_wpp.csv -> ./resultados/wpp/prompt_role_dicionario_parte_1.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/prompt_role_dicionario_parte_1.csv
# Tempo total: 0.13 min | Tokens total: 5317
#
# Processando ../datasets/wpp/parte_2_wpp.csv -> ./resultados/wpp/prompt_role_dicionario_parte_2.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/prompt_role_dicionario_parte_2.csv
# Tempo total: 0.13 min | Tokens total: 4683
#
# Processando ../datasets/wpp/parte_3_wpp.csv -> ./resultados/wpp/prompt_role_dicionario_parte_3.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/prompt_role_dicionario_parte_3.csv
# Tempo total: 0.11 min | Tokens total: 4712
#
# Processando ../datasets/wpp/parte_4_wpp.csv -> ./resultados/wpp/prompt_role_dicionario_parte_4.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/prompt_role_dicionario_parte_4.csv
# Tempo total: 0.14 min | Tokens total: 4128
#
# Processando ../datasets/wpp/parte_5_wpp.csv -> ./resultados/wpp/prompt_role_dicionario_parte_5.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/prompt_role_dicionario_parte_5.csv
# Tempo total: 0.16 min | Tokens total: 4205
#
# Processando ../datasets/wpp/parte_6_wpp.csv -> ./resultados/wpp/prompt_role_dicionario_parte_6.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/prompt_role_dicionario_parte_6.csv
# Tempo total: 0.12 min | Tokens total: 4320
#
# Processando ../datasets/wpp/parte_7_wpp.csv -> ./resultados/wpp/prompt_role_dicionario_parte_7.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/prompt_role_dicionario_parte_7.csv
# Tempo total: 0.13 min | Tokens total: 4180
#
# Processando ../datasets/wpp/parte_8_wpp.csv -> ./resultados/wpp/prompt_role_dicionario_parte_8.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/prompt_role_dicionario_parte_8.csv
# Tempo total: 0.11 min | Tokens total: 5352
#
# Processando ../datasets/wpp/parte_9_wpp.csv -> ./resultados/wpp/prompt_role_dicionario_parte_9.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/prompt_role_dicionario_parte_9.csv
# Tempo total: 0.15 min | Tokens total: 4164
#
# Processando ../datasets/wpp/parte_10_wpp.csv -> ./resultados/wpp/prompt_role_dicionario_parte_10.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/prompt_role_dicionario_parte_10.csv
# Tempo total: 0.15 min | Tokens total: 5073
#
# Processando ../datasets/wpp/parte_11_wpp.csv -> ./resultados/wpp/prompt_role_dicionario_parte_11.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/prompt_role_dicionario_parte_11.csv
# Tempo total: 0.15 min | Tokens total: 4884
#
# Processando ../datasets/wpp/parte_12_wpp.csv -> ./resultados/wpp/prompt_role_dicionario_parte_12.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/prompt_role_dicionario_parte_12.csv
# Tempo total: 0.17 min | Tokens total: 4776

# %%
# === EXECUÇÃO DIC_COMPLETO  ===
with open("../datasets/dicionario_socialliwc.txt", "r", encoding="utf-8") as f:
    PROMPT_DIC = f.read()

inicio_total = time.time()
for i in range(1, 13):
    entrada = f"../datasets/wpp/parte_{i}_wpp.csv"
    saida = f"./resultados/wpp/prompt_dicionario_2_parte_{i}.csv"
    processar_arquivo(entrada, saida, PROMPT_DIC, "./resultados/wpp/prompt_role_dicionario_2_log_processamento.txt")
total_minutos = (time.time() - inicio_total) / 60
with open("./resultados/wpp/prompt_dicionario_2_tempo_execucao_wpp.txt", "a", encoding="utf-8") as f:
    f.write(f"\nTempo total de execução: {total_minutos:.2f} minutos\n")
# Out:
# Processando ../datasets/wpp/parte_1_wpp.csv -> ./resultados/wpp/prompt_role_dicionario_2_parte_1.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/prompt_role_dicionario_2_parte_1.csv
# Tempo total: 0.17 min | Tokens total: 8522
#
# Processando ../datasets/wpp/parte_2_wpp.csv -> ./resultados/wpp/prompt_role_dicionario_2_parte_2.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/prompt_role_dicionario_2_parte_2.csv
# Tempo total: 0.18 min | Tokens total: 7888
#
# Processando ../datasets/wpp/parte_3_wpp.csv -> ./resultados/wpp/prompt_role_dicionario_2_parte_3.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/prompt_role_dicionario_2_parte_3.csv
# Tempo total: 0.16 min | Tokens total: 7917
#
# Processando ../datasets/wpp/parte_4_wpp.csv -> ./resultados/wpp/prompt_role_dicionario_2_parte_4.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/prompt_role_dicionario_2_parte_4.csv
# Tempo total: 0.25 min | Tokens total: 7333
#
# Processando ../datasets/wpp/parte_5_wpp.csv -> ./resultados/wpp/prompt_role_dicionario_2_parte_5.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/prompt_role_dicionario_2_parte_5.csv
# Tempo total: 0.17 min | Tokens total: 7358
#
# Processando ../datasets/wpp/parte_6_wpp.csv -> ./resultados/wpp/prompt_role_dicionario_2_parte_6.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/prompt_role_dicionario_2_parte_6.csv
# Tempo total: 0.19 min | Tokens total: 7525
#
# Processando ../datasets/wpp/parte_7_wpp.csv -> ./resultados/wpp/prompt_role_dicionario_2_parte_7.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/prompt_role_dicionario_2_parte_7.csv
# Tempo total: 0.19 min | Tokens total: 7385
#
# Processando ../datasets/wpp/parte_8_wpp.csv -> ./resultados/wpp/prompt_role_dicionario_2_parte_8.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/prompt_role_dicionario_2_parte_8.csv
# Tempo total: 0.19 min | Tokens total: 8557
#
# Processando ../datasets/wpp/parte_9_wpp.csv -> ./resultados/wpp/prompt_role_dicionario_2_parte_9.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/prompt_role_dicionario_2_parte_9.csv
# Tempo total: 0.20 min | Tokens total: 7369
#
# Processando ../datasets/wpp/parte_10_wpp.csv -> ./resultados/wpp/prompt_role_dicionario_2_parte_10.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/prompt_role_dicionario_2_parte_10.csv
# Tempo total: 0.19 min | Tokens total: 8278
#
# Processando ../datasets/wpp/parte_11_wpp.csv -> ./resultados/wpp/prompt_role_dicionario_2_parte_11.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/prompt_role_dicionario_2_parte_11.csv
# Tempo total: 0.20 min | Tokens total: 8089
#
# Processando ../datasets/wpp/parte_12_wpp.csv -> ./resultados/wpp/prompt_role_dicionario_2_parte_12.csv
# Lote 1/1 - 50 textos
# Arquivo salvo em ./resultados/wpp/prompt_role_dicionario_2_parte_12.csv
# Tempo total: 0.19 min | Tokens total: 7981

# %% [markdown]
# ## Processamento - Zero Shot

# %%
# Junção dos dados

all_files = glob.glob("./resultados/wpp/zero_shot*.csv") 

li = []

for filename in all_files:
    df = pd.read_csv(filename) # Lê cada arquivo CSV
    li.append(df) # Adiciona o DataFrame lido à lista

# Concatena todos os DataFrames em um único DataFrame
final_df = pd.concat(li, axis=0, ignore_index=False) # axis=0 para empilhar as linhas
                                                    # ignore_index = False mantem o index original

print(f"Total de {len(all_files)} arquivos combinados.")
print(f"O DataFrame final tem {final_df.shape[0]} linhas e {final_df.shape[1]} colunas.")

# Para salvar o DataFrame combinado em um novo arquivo CSV
final_df.to_csv("./resultados/wpp/arquivo_combinado_zeroShot_wpp.csv", index=False)
print("Arquivo 'arquivo_combinado_zeroShot_wpp.csv' criado com sucesso!")
# Out:
# Total de 12 arquivos combinados.
# O DataFrame final tem 600 linhas e 3 colunas.
# Arquivo 'arquivo_combinado_zeroShot_wpp.csv' criado com sucesso!

# %%
df_combinado = pd.read_csv('./resultados/wpp/arquivo_combinado_zeroShot_wpp.csv')
df_combinado.head()
# Out:
#      id                             text_content_anonymous  rotulo_modelo
# 0   632  É verdade, eu falei pro meu primo que é crente...              0
# 1  2572  *MST* faz barreira de contenção na *TRANSPOSIÇ...              1
# 2  2647  Nazismo e comunismo .\nTudo igual .\nA esquerd...              1
# 3   679  "o coração do sábio se inclina para direita, e...              1
# 4   752  "Os cristãos fiéis são como luz nesse mundo. B...              0

# %%
df_combinado['rotulo_modelo'].value_counts()
# Out:
# rotulo_modelo
# 1    336
# 0    264
# Name: count, dtype: int64

# %%
# Junção com o arquivo original

# Caminhos dos arquivos
arquivo_original = "../datasets/wpp/amostra_balanceada_com_rotulo.csv"   # contém: id, text_content_anonymous, rotulo
arquivo_llm = "./resultados/wpp/arquivo_combinado_zeroShot_wpp.csv"  # contém: id, text_content_anonymous, rotulo_modelo

# Lê os dois arquivos
df_original = pd.read_csv(arquivo_original, dtype=str)
df_llm = pd.read_csv(arquivo_llm, dtype=str)

# Renomeia a coluna da LLM para 'rotulo_chatgpt'
df_llm = df_llm.rename(columns={"rotulo_modelo": "rotulo_chatgpt"})

# Faz o merge pelo ID
df_combinado = pd.merge(
    df_original,
    df_llm[["id", "rotulo_chatgpt"]],  # só pega as colunas relevantes
    on="id",
    how="left"  # mantém todas as linhas do original
)

# Salva o resultado final
df_combinado.to_csv("./resultados/wpp/wpp_comparado_zeroShot.csv", index=False, encoding="utf-8")

print("✅ Arquivo combinado criado com sucesso!")
print(f"O DataFrame final tem {df_combinado.shape[0]} linhas e {df_combinado.shape[1]} colunas.")
# Out:
# ✅ Arquivo combinado criado com sucesso!
# O DataFrame final tem 600 linhas e 4 colunas.

# %% [markdown]
# ## Processamento - Few Shot

# %%
# Junção dos dados

all_files = glob.glob("./resultados/wpp/few_shot_parte*.csv") 

li = []

for filename in all_files:
    df = pd.read_csv(filename) # Lê cada arquivo CSV
    li.append(df) # Adiciona o DataFrame lido à lista

# Concatena todos os DataFrames em um único DataFrame
final_df = pd.concat(li, axis=0, ignore_index=False) # axis=0 para empilhar as linhas
                                                    # ignore_index = False mantem o index original

print(f"Total de {len(all_files)} arquivos combinados.")
print(f"O DataFrame final tem {final_df.shape[0]} linhas e {final_df.shape[1]} colunas.")

# Para salvar o DataFrame combinado em um novo arquivo CSV
final_df.to_csv("./resultados/wpp/arquivo_combinado_fewShot_wpp.csv", index=False)
print("Arquivo 'arquivo_combinado_fewShot_wpp.csv' criado com sucesso!")
# Out:
# Total de 12 arquivos combinados.
# O DataFrame final tem 600 linhas e 3 colunas.
# Arquivo 'arquivo_combinado_fewShot_wpp.csv' criado com sucesso!

# %%
final_df['rotulo_modelo'].value_counts()
# Out:
# rotulo_modelo
# 1    305
# 0    295
# Name: count, dtype: int64

# %%
# Junção com o arquivo original

# Caminhos dos arquivos
arquivo_original = "../datasets/wpp/amostra_balanceada_com_rotulo.csv"   # contém: id, text_content_anonymous, rotulo
arquivo_llm = "./resultados/wpp/arquivo_combinado_fewShot_wpp.csv"  # contém: id, text_content_anonymous, rotulo_modelo

# Lê os dois arquivos
df_original = pd.read_csv(arquivo_original, dtype=str)
df_llm = pd.read_csv(arquivo_llm, dtype=str)

# Renomeia a coluna da LLM para 'rotulo_chatgpt'
df_llm = df_llm.rename(columns={"rotulo_modelo": "rotulo_chatgpt"})

# Faz o merge pelo ID
df_combinado = pd.merge(
    df_original,
    df_llm[["id", "rotulo_chatgpt"]],  # só pega as colunas relevantes
    on="id",
    how="left"  # mantém todas as linhas do original
)

# Salva o resultado final
df_combinado.to_csv("./resultados/wpp/wpp_comparado_fewShot.csv", index=False, encoding="utf-8")

print("✅ Arquivo combinado criado com sucesso!")
print(f"O DataFrame final tem {df_combinado.shape[0]} linhas e {df_combinado.shape[1]} colunas.")
# Out:
# ✅ Arquivo combinado criado com sucesso!
# O DataFrame final tem 600 linhas e 4 colunas.

# %% [markdown]
# ## Processamento Role Prompting

# %%
# Junção de arquivos 

all_files = glob.glob("./resultados/wpp/role_prompting*.csv") 

li = []

for filename in all_files:
    df = pd.read_csv(filename) # Lê cada arquivo CSV
    li.append(df) # Adiciona o DataFrame lido à lista

# Concatena todos os DataFrames em um único DataFrame
final_df = pd.concat(li, axis=0, ignore_index=False) # axis=0 para empilhar as linhas
                                                    # ignore_index = False mantem o index original

print(f"Total de {len(all_files)} arquivos combinados.")
print(f"O DataFrame final tem {final_df.shape[0]} linhas e {final_df.shape[1]} colunas.")

# Para salvar o DataFrame combinado em um novo arquivo CSV
final_df.to_csv("./resultados/wpp/arquivo_combinado_role_prompting_wpp.csv", index=False)
print("Arquivo 'arquivo_combinado_role_prompting_wpp.csv' criado com sucesso!")
# Out:
# Total de 12 arquivos combinados.
# O DataFrame final tem 600 linhas e 3 colunas.
# Arquivo 'arquivo_combinado_role_prompting_wpp.csv' criado com sucesso!

# %%
final_df = pd.read_csv('./resultados/wpp/arquivo_combinado_role_prompting_wpp.csv')
final_df.head()
# Out:
#      id                             text_content_anonymous  rotulo_modelo
# 0   632  É verdade, eu falei pro meu primo que é crente...              0
# 1  2572  *MST* faz barreira de contenção na *TRANSPOSIÇ...              1
# 2  2647  Nazismo e comunismo .\nTudo igual .\nA esquerd...              0
# 3   679  "o coração do sábio se inclina para direita, e...              0
# 4   752  "Os cristãos fiéis são como luz nesse mundo. B...              0

# %%
final_df['rotulo_modelo'].value_counts()
# Out:
# rotulo_modelo
# 1    309
# 0    291
# Name: count, dtype: int64

# %%
# Junção com arquivo original

# Caminhos dos arquivos
arquivo_original = "../datasets/wpp/amostra_balanceada_com_rotulo.csv"   # contém: id, text_content_anonymous, rotulo
arquivo_llm = "./resultados/wpp/arquivo_combinado_role_prompting_wpp.csv"  # contém: id, text_content_anonymous, rotulo_modelo

# Lê os dois arquivos
df_original = pd.read_csv(arquivo_original, dtype=str)
df_llm = pd.read_csv(arquivo_llm, dtype=str)

# Renomeia a coluna da LLM para 'rotulo_chatgpt'
df_llm = df_llm.rename(columns={"rotulo_modelo": "rotulo_chatgpt"})

# Faz o merge pelo ID
df_combinado = pd.merge(
    df_original,
    df_llm[["id", "rotulo_chatgpt"]],  # só pega as colunas relevantes
    on="id",
    how="left"  # mantém todas as linhas do original
)

# Salva o resultado final
df_combinado.to_csv("./resultados/wpp/wpp_comparado_role_prompting.csv", index=False, encoding="utf-8")

print(" Arquivo combinado criado com sucesso!")
print(f"O DataFrame final tem {df_combinado.shape[0]} linhas e {df_combinado.shape[1]} colunas.")
# Out:
#  Arquivo combinado criado com sucesso!
# O DataFrame final tem 600 linhas e 4 colunas.

# %% [markdown]
# ## Processamento Role + Dicionário

# %%
# Junção de arquivos 

all_files = glob.glob("./resultados/wpp/prompt_role_dicionario_parte*.csv") 

li = []

for filename in all_files:
    df = pd.read_csv(filename) # Lê cada arquivo CSV
    li.append(df) # Adiciona o DataFrame lido à lista

# Concatena todos os DataFrames em um único DataFrame
final_df = pd.concat(li, axis=0, ignore_index=False) # axis=0 para empilhar as linhas
                                                    # ignore_index = False mantem o index original

print(f"Total de {len(all_files)} arquivos combinados.")
print(f"O DataFrame final tem {final_df.shape[0]} linhas e {final_df.shape[1]} colunas.")

# Para salvar o DataFrame combinado em um novo arquivo CSV
final_df.to_csv("./resultados/wpp/arquivo_combinado_role_prompting_dic_wpp.csv", index=False)
print("Arquivo 'arquivo_combinado_role_prompting_dic_wpp.csv' criado com sucesso!")
# Out:
# Total de 12 arquivos combinados.
# O DataFrame final tem 600 linhas e 3 colunas.
# Arquivo 'arquivo_combinado_role_prompting_dic_wpp.csv' criado com sucesso!

# %%
final_df['rotulo_modelo'].value_counts()
# Out:
# rotulo_modelo
# 0    313
# 1    287
# Name: count, dtype: int64

# %%
# Junção com arquivo original

# Caminhos dos arquivos
arquivo_original = "../datasets/wpp/amostra_balanceada_com_rotulo.csv"   # contém: id, text_content_anonymous, rotulo
arquivo_llm = "./resultados/wpp/arquivo_combinado_role_prompting_dic_wpp.csv"  # contém: id, text_content_anonymous, rotulo_modelo

# Lê os dois arquivos
df_original = pd.read_csv(arquivo_original, dtype=str)
df_llm = pd.read_csv(arquivo_llm, dtype=str)

# Renomeia a coluna da LLM para 'rotulo_chatgpt'
df_llm = df_llm.rename(columns={"rotulo_modelo": "rotulo_chatgpt"})

# Faz o merge pelo ID
df_combinado = pd.merge(
    df_original,
    df_llm[["id", "rotulo_chatgpt"]],  # só pega as colunas relevantes
    on="id",
    how="left"  # mantém todas as linhas do original
)

# Salva o resultado final
df_combinado.to_csv("./resultados/wpp/wpp_comparado_role_prompting_dic.csv", index=False, encoding="utf-8")

print(" Arquivo combinado criado com sucesso!")
print(f"O DataFrame final tem {df_combinado.shape[0]} linhas e {df_combinado.shape[1]} colunas.")
# Out:
#  Arquivo combinado criado com sucesso!
# O DataFrame final tem 600 linhas e 4 colunas.

# %% [markdown]
# ## Processamento ROLE + DIC_COMPLETO

# %%
# Junção de arquivos 

all_files = glob.glob("./resultados/wpp/prompt_role_dicionario_2*.csv") 

li = []

for filename in all_files:
    df = pd.read_csv(filename) # Lê cada arquivo CSV
    li.append(df) # Adiciona o DataFrame lido à lista

# Concatena todos os DataFrames em um único DataFrame
final_df = pd.concat(li, axis=0, ignore_index=False) # axis=0 para empilhar as linhas
                                                    # ignore_index = False mantem o index original

print(f"Total de {len(all_files)} arquivos combinados.")
print(f"O DataFrame final tem {final_df.shape[0]} linhas e {final_df.shape[1]} colunas.")

# Para salvar o DataFrame combinado em um novo arquivo CSV
final_df.to_csv("./resultados/wpp/arquivo_combinado_role_prompting_dic_2_wpp.csv", index=False)
print("Arquivo 'arquivo_combinado_role_prompting_dic_2_wpp.csv' criado com sucesso!")
# Out:
# Total de 12 arquivos combinados.
# O DataFrame final tem 600 linhas e 3 colunas.
# Arquivo 'arquivo_combinado_role_prompting_dic_2_wpp.csv' criado com sucesso!

# %%
final_df['rotulo_modelo'].value_counts()
# Out:
# rotulo_modelo
# 1    311
# 0    289
# Name: count, dtype: int64

# %%
# Junção com arquivo original

# Caminhos dos arquivos
arquivo_original = "../datasets/wpp/amostra_balanceada_com_rotulo.csv"   # contém: id, text_content_anonymous, rotulo
arquivo_llm = "./resultados/wpp/arquivo_combinado_role_prompting_dic_2_wpp.csv"  # contém: id, text_content_anonymous, rotulo_modelo

# Lê os dois arquivos
df_original = pd.read_csv(arquivo_original, dtype=str)
df_llm = pd.read_csv(arquivo_llm, dtype=str)

# Renomeia a coluna da LLM para 'rotulo_chatgpt'
df_llm = df_llm.rename(columns={"rotulo_modelo": "rotulo_chatgpt"})

# Faz o merge pelo ID
df_combinado = pd.merge(
    df_original,
    df_llm[["id", "rotulo_chatgpt"]],  # só pega as colunas relevantes
    on="id",
    how="left"  # mantém todas as linhas do original
)

# Salva o resultado final
df_combinado.to_csv("./resultados/wpp/wpp_comparado_role_prompting_dic_2.csv", index=False, encoding="utf-8")

print(" Arquivo combinado criado com sucesso!")
print(f"O DataFrame final tem {df_combinado.shape[0]} linhas e {df_combinado.shape[1]} colunas.")
# Out:
#  Arquivo combinado criado com sucesso!
# O DataFrame final tem 600 linhas e 4 colunas.

# %% [markdown]
# ## Pré processamento Role + dic + few shot

# %%
# Junção de arquivos 

all_files = glob.glob("./resultados/wpp/prompt_role_dicionario_few_shot*.csv") 

li = []

for filename in all_files:
    df = pd.read_csv(filename) # Lê cada arquivo CSV
    li.append(df) # Adiciona o DataFrame lido à lista

# Concatena todos os DataFrames em um único DataFrame
final_df = pd.concat(li, axis=0, ignore_index=False) # axis=0 para empilhar as linhas
                                                    # ignore_index = False mantem o index original

print(f"Total de {len(all_files)} arquivos combinados.")
print(f"O DataFrame final tem {final_df.shape[0]} linhas e {final_df.shape[1]} colunas.")

# Para salvar o DataFrame combinado em um novo arquivo CSV
final_df.to_csv("./resultados/wpp/arquivo_combinado_role_prompting_dic_few_shot_wpp.csv", index=False)
print("Arquivo 'arquivo_combinado_role_prompting_dic_few_shot_wpp.csv' criado com sucesso!")
# Out:
# Total de 12 arquivos combinados.
# O DataFrame final tem 600 linhas e 3 colunas.
# Arquivo 'arquivo_combinado_role_prompting_dic_few_shot_wpp.csv' criado com sucesso!

# %%
final_df['rotulo_modelo'].value_counts()
# Out:
# rotulo_modelo
# 1    316
# 0    284
# Name: count, dtype: int64

# %%
# Junção com arquivo original

# Caminhos dos arquivos
arquivo_original = "../datasets/wpp/amostra_balanceada_com_rotulo.csv"   # contém: id, text_content_anonymous, rotulo
arquivo_llm = "./resultados/wpp/arquivo_combinado_role_prompting_dic_few_shot_wpp.csv"  # contém: id, text_content_anonymous, rotulo_modelo

# Lê os dois arquivos
df_original = pd.read_csv(arquivo_original, dtype=str)
df_llm = pd.read_csv(arquivo_llm, dtype=str)

# Renomeia a coluna da LLM para 'rotulo_chatgpt'
df_llm = df_llm.rename(columns={"rotulo_modelo": "rotulo_chatgpt"})

# Faz o merge pelo ID
df_combinado = pd.merge(
    df_original,
    df_llm[["id", "rotulo_chatgpt"]],  # só pega as colunas relevantes
    on="id",
    how="left"  # mantém todas as linhas do original
)

# Salva o resultado final
df_combinado.to_csv("./resultados/wpp/wpp_comparado_role_prompting_dic_few_shot.csv", index=False, encoding="utf-8")

print(" Arquivo combinado criado com sucesso!")
print(f"O DataFrame final tem {df_combinado.shape[0]} linhas e {df_combinado.shape[1]} colunas.")
# Out:
#  Arquivo combinado criado com sucesso!
# O DataFrame final tem 600 linhas e 4 colunas.

# %% [markdown]
# ## role + few shot

# %%
# Junção de arquivos 

all_files = glob.glob("./resultados/wpp/prompt_role_few_shot*.csv") 

li = []

for filename in all_files:
    df = pd.read_csv(filename) # Lê cada arquivo CSV
    li.append(df) # Adiciona o DataFrame lido à lista

# Concatena todos os DataFrames em um único DataFrame
final_df = pd.concat(li, axis=0, ignore_index=False) # axis=0 para empilhar as linhas
                                                    # ignore_index = False mantem o index original

print(f"Total de {len(all_files)} arquivos combinados.")
print(f"O DataFrame final tem {final_df.shape[0]} linhas e {final_df.shape[1]} colunas.")

# Para salvar o DataFrame combinado em um novo arquivo CSV
final_df.to_csv("./resultados/wpp/arquivo_combinado_role_prompting_few_shot_wpp.csv", index=False)
print("Arquivo 'arquivo_combinado_role_prompting_few_shot_wpp.csv' criado com sucesso!")
# Out:
# Total de 12 arquivos combinados.
# O DataFrame final tem 600 linhas e 3 colunas.
# Arquivo 'arquivo_combinado_role_prompting_few_shot_wpp.csv' criado com sucesso!

# %%
final_df['rotulo_modelo'].value_counts()
# Out:
# rotulo_modelo
# 0    305
# 1    295
# Name: count, dtype: int64

# %%
# Junção com arquivo original

# Caminhos dos arquivos
arquivo_original = "../datasets/wpp/amostra_balanceada_com_rotulo.csv"   # contém: id, text_content_anonymous, rotulo
arquivo_llm = "./resultados/wpp/arquivo_combinado_role_prompting_few_shot_wpp.csv"  # contém: id, text_content_anonymous, rotulo_modelo

# Lê os dois arquivos
df_original = pd.read_csv(arquivo_original, dtype=str)
df_llm = pd.read_csv(arquivo_llm, dtype=str)

# Renomeia a coluna da LLM para 'rotulo_chatgpt'
df_llm = df_llm.rename(columns={"rotulo_modelo": "rotulo_chatgpt"})

# Faz o merge pelo ID
df_combinado = pd.merge(
    df_original,
    df_llm[["id", "rotulo_chatgpt"]],  # só pega as colunas relevantes
    on="id",
    how="left"  # mantém todas as linhas do original
)

# Salva o resultado final
df_combinado.to_csv("./resultados/wpp/wpp_comparado_role_prompting_few_shot.csv", index=False, encoding="utf-8")

print(" Arquivo combinado criado com sucesso!")
print(f"O DataFrame final tem {df_combinado.shape[0]} linhas e {df_combinado.shape[1]} colunas.")
# Out:
#  Arquivo combinado criado com sucesso!
# O DataFrame final tem 600 linhas e 4 colunas.

# %% [markdown]
# ## few shot mais

# %%
# Junção de arquivos 

all_files = glob.glob("./resultados/wpp/few_shot_mais*.csv") 

li = []

for filename in all_files:
    df = pd.read_csv(filename) # Lê cada arquivo CSV
    li.append(df) # Adiciona o DataFrame lido à lista

# Concatena todos os DataFrames em um único DataFrame
final_df = pd.concat(li, axis=0, ignore_index=False) # axis=0 para empilhar as linhas
                                                    # ignore_index = False mantem o index original

print(f"Total de {len(all_files)} arquivos combinados.")
print(f"O DataFrame final tem {final_df.shape[0]} linhas e {final_df.shape[1]} colunas.")

# Para salvar o DataFrame combinado em um novo arquivo CSV
final_df.to_csv("./resultados/wpp/arquivo_combinadofew_shot_mais_wpp.csv", index=False)
print("Arquivo 'arquivo_combinado_few_shot_mais_wpp.csv' criado com sucesso!")
# Out:
# Total de 12 arquivos combinados.
# O DataFrame final tem 600 linhas e 3 colunas.
# Arquivo 'arquivo_combinado_few_shot_mais_wpp.csv' criado com sucesso!

# %%
final_df['rotulo_modelo'].value_counts()
# Out:
# rotulo_modelo
# 1    313
# 0    287
# Name: count, dtype: int64

# %%
# Junção com arquivo original

# Caminhos dos arquivos
arquivo_original = "../datasets/wpp/amostra_balanceada_com_rotulo.csv"   # contém: id, text_content_anonymous, rotulo
arquivo_llm = "./resultados/wpp/arquivo_combinadofew_shot_mais_wpp.csv"  # contém: id, text_content_anonymous, rotulo_modelo

# Lê os dois arquivos
df_original = pd.read_csv(arquivo_original, dtype=str)
df_llm = pd.read_csv(arquivo_llm, dtype=str)

# Renomeia a coluna da LLM para 'rotulo_chatgpt'
df_llm = df_llm.rename(columns={"rotulo_modelo": "rotulo_chatgpt"})

# Faz o merge pelo ID
df_combinado = pd.merge(
    df_original,
    df_llm[["id", "rotulo_chatgpt"]],  # só pega as colunas relevantes
    on="id",
    how="left"  # mantém todas as linhas do original
)

# Salva o resultado final
df_combinado.to_csv("./resultados/wpp/wpp_comparado_few_shot_mais.csv", index=False, encoding="utf-8")

print(" Arquivo combinado criado com sucesso!")
print(f"O DataFrame final tem {df_combinado.shape[0]} linhas e {df_combinado.shape[1]} colunas.")
# Out:
#  Arquivo combinado criado com sucesso!
# O DataFrame final tem 600 linhas e 4 colunas.

# %%
# Junção de arquivos 

all_files = glob.glob("./resultados/wpp/zero_shot_dic_parte_*.csv") 

li = []

for filename in all_files:
    df = pd.read_csv(filename) # Lê cada arquivo CSV
    li.append(df) # Adiciona o DataFrame lido à lista

# Concatena todos os DataFrames em um único DataFrame
final_df = pd.concat(li, axis=0, ignore_index=False) # axis=0 para empilhar as linhas
                                                    # ignore_index = False mantem o index original

print(f"Total de {len(all_files)} arquivos combinados.")
print(f"O DataFrame final tem {final_df.shape[0]} linhas e {final_df.shape[1]} colunas.")

# Para salvar o DataFrame combinado em um novo arquivo CSV
final_df.to_csv("./resultados/wpp/arquivo_combinado_zero_shot_dic_wpp.csv", index=False)
print("Arquivo 'arquivo_combinado_zero_shot_dic_wpp.csv' criado com sucesso!")
# Out:
# Total de 12 arquivos combinados.
# O DataFrame final tem 600 linhas e 3 colunas.
# Arquivo 'arquivo_combinado_zero_shot_dic_wpp.csv' criado com sucesso!

# %%
final_df['rotulo_modelo'].value_counts()
# Out:
# rotulo_modelo
# 1    333
# 0    267
# Name: count, dtype: int64

# %%
# Junção com arquivo original

# Caminhos dos arquivos
arquivo_original = "../datasets/wpp/amostra_balanceada_com_rotulo.csv"   # contém: id, text_content_anonymous, rotulo
arquivo_llm = "./resultados/wpp/arquivo_combinado_zero_shot_dic_wpp.csv"  # contém: id, text_content_anonymous, rotulo_modelo

# Lê os dois arquivos
df_original = pd.read_csv(arquivo_original, dtype=str)
df_llm = pd.read_csv(arquivo_llm, dtype=str)

# Renomeia a coluna da LLM para 'rotulo_chatgpt'
df_llm = df_llm.rename(columns={"rotulo_modelo": "rotulo_chatgpt"})

# Faz o merge pelo ID
df_combinado = pd.merge(
    df_original,
    df_llm[["id", "rotulo_chatgpt"]],  # só pega as colunas relevantes
    on="id",
    how="left"  # mantém todas as linhas do original
)

# Salva o resultado final
df_combinado.to_csv("./resultados/wpp/wpp_comparado_zero_shot_dic.csv", index=False, encoding="utf-8")

print(" Arquivo combinado criado com sucesso!")
print(f"O DataFrame final tem {df_combinado.shape[0]} linhas e {df_combinado.shape[1]} colunas.")
# Out:
#  Arquivo combinado criado com sucesso!
# O DataFrame final tem 600 linhas e 4 colunas.

# %% [markdown]
# ## Calculando métricas

# %% [markdown]
# ### Zero Shot

# %%
# Lê o arquivo combinado
df = pd.read_csv("./resultados/wpp/wpp_comparado_zeroShot.csv")

# Converte as colunas para inteiro
df["preconceito"] = pd.to_numeric(df["preconceito"], errors="coerce")
df["rotulo_chatgpt"] = pd.to_numeric(df["rotulo_chatgpt"], errors="coerce")

# Remove linhas com valores ausentes
df = df.dropna(subset=["preconceito", "rotulo_chatgpt"])

y_true = df["preconceito"].values
y_pred = df["rotulo_chatgpt"].values

# Parâmetros do bootstrap
n_bootstrap = 1000  # número de repetições
rng = np.random.default_rng(42)

# Armazena métricas de cada repetição
metrics = {
    "accuracy": [],
    "precision": [],
    "recall": [],
    "f1": [],
    "auc": []
}

for _ in range(n_bootstrap):
    idx = rng.integers(0, len(y_true), len(y_true))
    y_true_sample = y_true[idx]
    y_pred_sample = y_pred[idx]

    metrics["accuracy"].append(accuracy_score(y_true_sample, y_pred_sample))
    metrics["precision"].append(precision_score(y_true_sample, y_pred_sample, zero_division=0))
    metrics["recall"].append(recall_score(y_true_sample, y_pred_sample, zero_division=0))
    metrics["f1"].append(f1_score(y_true_sample, y_pred_sample, zero_division=0))
    metrics["auc"].append(roc_auc_score(y_true_sample, y_pred_sample))

# Calcula média e desvio padrão
resultados = {m: (np.mean(vals), np.std(vals)) for m, vals in metrics.items()}

print("\n Resultados de avaliação (média ± desvio padrão):")
for m, (media, desvio) in resultados.items():
    print(f"{m.capitalize()}: {media:.4f} ± {desvio:.4f}")

# --- Matriz de confusão ---
cm = confusion_matrix(y_true, y_pred)


# --- Visualização da matriz ---
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["0", "1"])
disp.plot(cmap="Blues", values_format="d")
plt.title("Confusion Matrix — Zero-Shot (LLM vs Anotadores)")
plt.savefig("./resultados/wpp/matriz_confusao_zero_shot.png", dpi=300, bbox_inches="tight")
plt.show()

# Salva os resultados
with open("./resultados/wpp/metricas_avaliacao_zeroShot_bootstrap.txt", "w", encoding="utf-8") as f:
    f.write(" MÉTRICAS DE AVALIAÇÃO COM BOOTSTRAP (LLM vs Anotadores)\n\n")
    f.write(f"Total de exemplos avaliados: {len(df)}\n")
    for m, (media, desvio) in resultados.items():
        f.write(f"{m.capitalize()}: {media:.4f} ± {desvio:.4f}\n")
# Out:
#  Resultados de avaliação (média ± desvio padrão):
# Accuracy: 0.8003 ± 0.0162
# Precision: 0.7678 ± 0.0229
# Recall: 0.8615 ± 0.0194
# F1: 0.8117 ± 0.0168
# Auc: 0.8002 ± 0.0160

# %% [markdown]
# ### Few Shot

# %%
# Lê o arquivo combinado
df = pd.read_csv("./resultados/wpp/wpp_comparado_fewShot.csv")

# Converte as colunas para inteiro
df["preconceito"] = pd.to_numeric(df["preconceito"], errors="coerce")
df["rotulo_chatgpt"] = pd.to_numeric(df["rotulo_chatgpt"], errors="coerce")

# Remove linhas com valores ausentes
df = df.dropna(subset=["preconceito", "rotulo_chatgpt"])

y_true = df["preconceito"].values
y_pred = df["rotulo_chatgpt"].values

# Parâmetros do bootstrap
n_bootstrap = 1000  # número de repetições
rng = np.random.default_rng(42)

# Armazena métricas de cada repetição
metrics = {
    "accuracy": [],
    "precision": [],
    "recall": [],
    "f1": [],
    "auc": []
}

for _ in range(n_bootstrap):
    idx = rng.integers(0, len(y_true), len(y_true))
    y_true_sample = y_true[idx]
    y_pred_sample = y_pred[idx]

    metrics["accuracy"].append(accuracy_score(y_true_sample, y_pred_sample))
    metrics["precision"].append(precision_score(y_true_sample, y_pred_sample, zero_division=0))
    metrics["recall"].append(recall_score(y_true_sample, y_pred_sample, zero_division=0))
    metrics["f1"].append(f1_score(y_true_sample, y_pred_sample, zero_division=0))
    metrics["auc"].append(roc_auc_score(y_true_sample, y_pred_sample))

# Calcula média e desvio padrão
resultados = {m: (np.mean(vals), np.std(vals)) for m, vals in metrics.items()}

# --- Matriz de confusão ---
cm = confusion_matrix(y_true, y_pred)

# --- Visualização da matriz ---
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["0", "1"])
disp.plot(cmap="Blues", values_format="d")
plt.title("Confusion Matrix — Few-Shot (LLM vs Anotadores)")
plt.savefig("./resultados/wpp/matriz_confusao_few_shot.png", dpi=300, bbox_inches="tight")
plt.show()

print("\n Resultados de avaliação (média ± desvio padrão):")
for m, (media, desvio) in resultados.items():
    print(f"{m.capitalize()}: {media:.4f} ± {desvio:.4f}")

# Salva os resultados
with open("./resultados/wpp/metricas_avaliacao_fewShot_bootstrap.txt", "w", encoding="utf-8") as f:
    f.write(" MÉTRICAS DE AVALIAÇÃO COM BOOTSTRAP (LLM vs Anotadores)\n\n")
    f.write(f"Total de exemplos avaliados: {len(df)}\n")
    for m, (media, desvio) in resultados.items():
        f.write(f"{m.capitalize()}: {media:.4f} ± {desvio:.4f}\n")
# Out:
#  Resultados de avaliação (média ± desvio padrão):
# Accuracy: 0.7912 ± 0.0166
# Precision: 0.7864 ± 0.0235
# Recall: 0.8000 ± 0.0230
# F1: 0.7929 ± 0.0182
# Auc: 0.7912 ± 0.0166

# %% [markdown]
# ### Role Prompting

# %%
# Lê o arquivo combinado
df = pd.read_csv("./resultados/wpp/wpp_comparado_role_prompting.csv")

# Converte as colunas para inteiro
df["preconceito"] = pd.to_numeric(df["preconceito"], errors="coerce")
df["rotulo_chatgpt"] = pd.to_numeric(df["rotulo_chatgpt"], errors="coerce")

# Remove linhas com valores ausentes
df = df.dropna(subset=["preconceito", "rotulo_chatgpt"])

y_true = df["preconceito"].values
y_pred = df["rotulo_chatgpt"].values

# Parâmetros do bootstrap
n_bootstrap = 1000  # número de repetições
rng = np.random.default_rng(42)

# Armazena métricas de cada repetição
metrics = {
    "accuracy": [],
    "precision": [],
    "recall": [],
    "f1": [],
    "auc": []
}

for _ in range(n_bootstrap):
    idx = rng.integers(0, len(y_true), len(y_true))
    y_true_sample = y_true[idx]
    y_pred_sample = y_pred[idx]

    metrics["accuracy"].append(accuracy_score(y_true_sample, y_pred_sample))
    metrics["precision"].append(precision_score(y_true_sample, y_pred_sample, zero_division=0))
    metrics["recall"].append(recall_score(y_true_sample, y_pred_sample, zero_division=0))
    metrics["f1"].append(f1_score(y_true_sample, y_pred_sample, zero_division=0))
    metrics["auc"].append(roc_auc_score(y_true_sample, y_pred_sample))

# Calcula média e desvio padrão
resultados = {m: (np.mean(vals), np.std(vals)) for m, vals in metrics.items()}

# --- Matriz de confusão ---
cm = confusion_matrix(y_true, y_pred)

# --- Visualização da matriz ---
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["0", "1"])
disp.plot(cmap="Blues", values_format="d")
# Alterando os nomes dos eixos
disp.ax_.set_xlabel("Label Predita")
disp.ax_.set_ylabel("Label Verdadeira")
plt.title("Matriz de Confusão — Prompting por papel (LLM vs Anotadores)")
plt.savefig("./resultados/wpp/matriz_confusao_role_prompting_gpt_wpp.png", dpi=300, bbox_inches="tight")
plt.show()


print("\n Resultados de avaliação (média ± desvio padrão):")
for m, (media, desvio) in resultados.items():
    print(f"{m.capitalize()}: {media:.4f} ± {desvio:.4f}")

# Salva os resultados
with open("./resultados/wpp/metricas_avaliacao_role_prompting_bootstrap.txt", "w", encoding="utf-8") as f:
    f.write(" MÉTRICAS DE AVALIAÇÃO COM BOOTSTRAP (LLM vs Anotadores)\n\n")
    f.write(f"Total de exemplos avaliados: {len(df)}\n")
    for m, (media, desvio) in resultados.items():
        f.write(f"{m.capitalize()}: {media:.4f} ± {desvio:.4f}\n")
# Out:
#  Resultados de avaliação (média ± desvio padrão):
# Accuracy: 0.8345 ± 0.0150
# Precision: 0.8247 ± 0.0215
# Recall: 0.8501 ± 0.0204
# F1: 0.8370 ± 0.0159
# Auc: 0.8345 ± 0.0149

# %% [markdown]
# ### Role + DIC COMPLETO

# %%
# Lê o arquivo combinado
df = pd.read_csv("./resultados/wpp/wpp_comparado_role_prompting_dic_2.csv")

# Converte as colunas para inteiro
df["preconceito"] = pd.to_numeric(df["preconceito"], errors="coerce")
df["rotulo_chatgpt"] = pd.to_numeric(df["rotulo_chatgpt"], errors="coerce")

# Remove linhas com valores ausentes
df = df.dropna(subset=["preconceito", "rotulo_chatgpt"])

y_true = df["preconceito"].values
y_pred = df["rotulo_chatgpt"].values

# Parâmetros do bootstrap
n_bootstrap = 1000  # número de repetições
rng = np.random.default_rng(42)

# Armazena métricas de cada repetição
metrics = {
    "accuracy": [],
    "precision": [],
    "recall": [],
    "f1": [],
    "auc": []
}

for _ in range(n_bootstrap):
    idx = rng.integers(0, len(y_true), len(y_true))
    y_true_sample = y_true[idx]
    y_pred_sample = y_pred[idx]

    metrics["accuracy"].append(accuracy_score(y_true_sample, y_pred_sample))
    metrics["precision"].append(precision_score(y_true_sample, y_pred_sample, zero_division=0))
    metrics["recall"].append(recall_score(y_true_sample, y_pred_sample, zero_division=0))
    metrics["f1"].append(f1_score(y_true_sample, y_pred_sample, zero_division=0))
    metrics["auc"].append(roc_auc_score(y_true_sample, y_pred_sample))

# Calcula média e desvio padrão
resultados = {m: (np.mean(vals), np.std(vals)) for m, vals in metrics.items()}

# --- Matriz de confusão ---
cm = confusion_matrix(y_true, y_pred)

# --- Visualização da matriz ---
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["0", "1"])
disp.plot(cmap="Blues", values_format="d")
plt.title("Confusion Matrix — Using Dictionary (LLM vs Anotadores)")
plt.savefig("./resultados/wpp/matriz_confusao_role_prompting_dic.png", dpi=300, bbox_inches="tight")
plt.show()

print("\n Resultados de avaliação (média ± desvio padrão):")
for m, (media, desvio) in resultados.items():
    print(f"{m.capitalize()}: {media:.4f} ± {desvio:.4f}")

# Salva os resultados
with open("./resultados/wpp/metricas_avaliacao_role_prompting_dic_2_bootstrap.txt", "w", encoding="utf-8") as f:
    f.write(" MÉTRICAS DE AVALIAÇÃO COM BOOTSTRAP (LLM vs Anotadores)\n\n")
    f.write(f"Total de exemplos avaliados: {len(df)}\n")
    for m, (media, desvio) in resultados.items():
        f.write(f"{m.capitalize()}: {media:.4f} ± {desvio:.4f}\n")
# Out:
#  Resultados de avaliação (média ± desvio padrão):
# Accuracy: 0.8310 ± 0.0152
# Precision: 0.8196 ± 0.0212
# Recall: 0.8492 ± 0.0206
# F1: 0.8339 ± 0.0161
# Auc: 0.8310 ± 0.0152

# %% [markdown]
# ### role prompting + few shot

# %%
# Lê o arquivo combinado
df = pd.read_csv("./resultados/wpp/wpp_comparado_role_prompting_few_shot.csv")

# Converte as colunas para inteiro
df["preconceito"] = pd.to_numeric(df["preconceito"], errors="coerce")
df["rotulo_chatgpt"] = pd.to_numeric(df["rotulo_chatgpt"], errors="coerce")

# Remove linhas com valores ausentes
df = df.dropna(subset=["preconceito", "rotulo_chatgpt"])

y_true = df["preconceito"].values
y_pred = df["rotulo_chatgpt"].values

# Parâmetros do bootstrap
n_bootstrap = 1000  # número de repetições
rng = np.random.default_rng(42)

# Armazena métricas de cada repetição
metrics = {
    "accuracy": [],
    "precision": [],
    "recall": [],
    "f1": [],
    "auc": []
}

for _ in range(n_bootstrap):
    idx = rng.integers(0, len(y_true), len(y_true))
    y_true_sample = y_true[idx]
    y_pred_sample = y_pred[idx]

    metrics["accuracy"].append(accuracy_score(y_true_sample, y_pred_sample))
    metrics["precision"].append(precision_score(y_true_sample, y_pred_sample, zero_division=0))
    metrics["recall"].append(recall_score(y_true_sample, y_pred_sample, zero_division=0))
    metrics["f1"].append(f1_score(y_true_sample, y_pred_sample, zero_division=0))
    metrics["auc"].append(roc_auc_score(y_true_sample, y_pred_sample))

# Calcula média e desvio padrão
resultados = {m: (np.mean(vals), np.std(vals)) for m, vals in metrics.items()}

print("\n Resultados de avaliação (média ± desvio padrão):")
for m, (media, desvio) in resultados.items():
    print(f"{m.capitalize()}: {media:.4f} ± {desvio:.4f}")

# Salva os resultados
with open("./resultados/wpp/metricas_avaliacao_role_prompting_few_shot_bootstrap.txt", "w", encoding="utf-8") as f:
    f.write(" MÉTRICAS DE AVALIAÇÃO COM BOOTSTRAP (LLM vs Anotadores)\n\n")
    f.write(f"Total de exemplos avaliados: {len(df)}\n")
    for m, (media, desvio) in resultados.items():
        f.write(f"{m.capitalize()}: {media:.4f} ± {desvio:.4f}\n")
# Out:
#  Resultados de avaliação (média ± desvio padrão):
# Accuracy: 0.8380 ± 0.0146
# Precision: 0.8438 ± 0.0204
# Recall: 0.8299 ± 0.0215
# F1: 0.8366 ± 0.0158
# Auc: 0.8380 ± 0.0145

# %% [markdown]
# ### ZERO SHOT + DIC

# %%
# Lê o arquivo combinado
df = pd.read_csv("./resultados/wpp/wpp_comparado_zero_shot_dic.csv")

# Converte as colunas para inteiro
df["preconceito"] = pd.to_numeric(df["preconceito"], errors="coerce")
df["rotulo_chatgpt"] = pd.to_numeric(df["rotulo_chatgpt"], errors="coerce")

# Remove linhas com valores ausentes
df = df.dropna(subset=["preconceito", "rotulo_chatgpt"])

y_true = df["preconceito"].values
y_pred = df["rotulo_chatgpt"].values

# Parâmetros do bootstrap
n_bootstrap = 1000  # número de repetições
rng = np.random.default_rng(42)

# Armazena métricas de cada repetição
metrics = {
    "accuracy": [],
    "precision": [],
    "recall": [],
    "f1": [],
    "auc": []
}

for _ in range(n_bootstrap):
    idx = rng.integers(0, len(y_true), len(y_true))
    y_true_sample = y_true[idx]
    y_pred_sample = y_pred[idx]

    metrics["accuracy"].append(accuracy_score(y_true_sample, y_pred_sample))
    metrics["precision"].append(precision_score(y_true_sample, y_pred_sample, zero_division=0))
    metrics["recall"].append(recall_score(y_true_sample, y_pred_sample, zero_division=0))
    metrics["f1"].append(f1_score(y_true_sample, y_pred_sample, zero_division=0))
    metrics["auc"].append(roc_auc_score(y_true_sample, y_pred_sample))

# Calcula média e desvio padrão
resultados = {m: (np.mean(vals), np.std(vals)) for m, vals in metrics.items()}

print("\n Resultados de avaliação (média ± desvio padrão):")
for m, (media, desvio) in resultados.items():
    print(f"{m.capitalize()}: {media:.4f} ± {desvio:.4f}")

# Salva os resultados
with open("./resultados/wpp/metricas_avaliacao_zero_shot_dic_bootstrap.txt", "w", encoding="utf-8") as f:
    f.write(" MÉTRICAS DE AVALIAÇÃO COM BOOTSTRAP (LLM vs Anotadores)\n\n")
    f.write(f"Total de exemplos avaliados: {len(df)}\n")
    for m, (media, desvio) in resultados.items():
        f.write(f"{m.capitalize()}: {media:.4f} ± {desvio:.4f}\n")
# Out:
#  Resultados de avaliação (média ± desvio padrão):
# Accuracy: 0.8177 ± 0.0159
# Precision: 0.7862 ± 0.0219
# Recall: 0.8733 ± 0.0192
# F1: 0.8273 ± 0.0161
# Auc: 0.8177 ± 0.0157
